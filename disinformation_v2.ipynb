# %% [markdown]
# # Disinformation
#
# An example where an individual spreads a fake news among others and they discuss whether it is true or not, as well as some methods of preventing the spread of these.

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Import libraries

# %%
# !pip install --ignore-requires-python git+https://github.com/google-deepmind/concordia.git
# Out:
# Collecting git+https://github.com/google-deepmind/concordia.git
#   Cloning https://github.com/google-deepmind/concordia.git to /tmp/pip-req-build-0514fmha
#   Running command git clone --filter=blob:none --quiet https://github.com/google-deepmind/concordia.git /tmp/pip-req-build-0514fmha
#   Resolved https://github.com/google-deepmind/concordia.git to commit 87d53dd2c6a93947017081344d0445bc9bdbf636
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from gdm-concordia==1.6.0) (1.4.0)
# Collecting boto3 (from gdm-concordia==1.6.0)
#   Downloading boto3-1.34.150-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: google-cloud-aiplatform in /usr/local/lib/python3.10/dist-packages (from gdm-concordia==1.6.0) (1.59.0)
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.10/dist-packages (from gdm-concordia==1.6.0) (0.7.2)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from gdm-concordia==1.6.0) (7.34.0)
# Collecting langchain (from gdm-concordia==1.6.0)
#   Downloading langchain-0.2.11-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from gdm-concordia==1.6.0) (3.7.1)
# Collecting mistralai (from gdm-concordia==1.6.0)
#   Downloading mistralai-0.4.2-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from gdm-concordia==1.6.0) (1.26.4)
# Collecting openai>=1.3.0 (from gdm-concordia==1.6.0)
#   Using cached openai-1.37.1-py3-none-any.whl.metadata (22 kB)
# Collecting pandas<=2.0.3 (from gdm-concordia==1.6.0)
#   Downloading pandas-2.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from gdm-concordia==1.6.0) (2.8.2)
# Collecting reactivex (from gdm-concordia==1.6.0)
#   Downloading reactivex-4.0.4-py3-none-any.whl.metadata (5.5 kB)
# Collecting retry (from gdm-concordia==1.6.0)
#   Downloading retry-0.9.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from gdm-concordia==1.6.0) (1.13.1)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from gdm-concordia==1.6.0) (2.4.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from gdm-concordia==1.6.0) (4.42.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from gdm-concordia==1.6.0) (4.12.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.3.0->gdm-concordia==1.6.0) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.3.0->gdm-concordia==1.6.0) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai>=1.3.0->gdm-concordia==1.6.0)
#   Downloading httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.3.0->gdm-concordia==1.6.0) (2.8.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai>=1.3.0->gdm-concordia==1.6.0) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai>=1.3.0->gdm-concordia==1.6.0) (4.66.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<=2.0.3->gdm-concordia==1.6.0) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<=2.0.3->gdm-concordia==1.6.0) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->gdm-concordia==1.6.0) (1.16.0)
# Collecting botocore<1.35.0,>=1.34.150 (from boto3->gdm-concordia==1.6.0)
#   Downloading botocore-1.34.150-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->gdm-concordia==1.6.0)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3->gdm-concordia==1.6.0)
#   Downloading s3transfer-0.10.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform->gdm-concordia==1.6.0) (2.19.1)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform->gdm-concordia==1.6.0) (2.27.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform->gdm-concordia==1.6.0) (1.24.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform->gdm-concordia==1.6.0) (3.20.3)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform->gdm-concordia==1.6.0) (24.1)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform->gdm-concordia==1.6.0) (2.8.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform->gdm-concordia==1.6.0) (3.25.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform->gdm-concordia==1.6.0) (1.12.4)
# Requirement already satisfied: shapely<3.0.0dev in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform->gdm-concordia==1.6.0) (2.0.5)
# Requirement already satisfied: docstring-parser<1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform->gdm-concordia==1.6.0) (0.16)
# Requirement already satisfied: google-ai-generativelanguage==0.6.6 in /usr/local/lib/python3.10/dist-packages (from google-generativeai->gdm-concordia==1.6.0) (0.6.6)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.10/dist-packages (from google-generativeai->gdm-concordia==1.6.0) (2.137.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->gdm-concordia==1.6.0) (71.0.4)
# Collecting jedi>=0.16 (from ipython->gdm-concordia==1.6.0)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->gdm-concordia==1.6.0) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->gdm-concordia==1.6.0) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->gdm-concordia==1.6.0) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->gdm-concordia==1.6.0) (3.0.47)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->gdm-concordia==1.6.0) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->gdm-concordia==1.6.0) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->gdm-concordia==1.6.0) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->gdm-concordia==1.6.0) (4.9.0)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain->gdm-concordia==1.6.0) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain->gdm-concordia==1.6.0) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain->gdm-concordia==1.6.0) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain->gdm-concordia==1.6.0) (4.0.3)
# Collecting langchain-core<0.3.0,>=0.2.23 (from langchain->gdm-concordia==1.6.0)
#   Downloading langchain_core-0.2.24-py3-none-any.whl.metadata (6.2 kB)
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain->gdm-concordia==1.6.0)
#   Downloading langchain_text_splitters-0.2.2-py3-none-any.whl.metadata (2.1 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain->gdm-concordia==1.6.0)
#   Downloading langsmith-0.1.94-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain->gdm-concordia==1.6.0) (2.31.0)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain->gdm-concordia==1.6.0) (8.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gdm-concordia==1.6.0) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gdm-concordia==1.6.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gdm-concordia==1.6.0) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gdm-concordia==1.6.0) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gdm-concordia==1.6.0) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gdm-concordia==1.6.0) (3.1.2)
# Collecting orjson<3.11,>=3.9.10 (from mistralai->gdm-concordia==1.6.0)
#   Downloading orjson-3.10.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 3.4 MB/s eta 0:00:00
# Collecting py<2.0.0,>=1.4.26 (from retry->gdm-concordia==1.6.0)
#   Downloading py-1.11.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers->gdm-concordia==1.6.0) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers->gdm-concordia==1.6.0) (0.23.5)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->gdm-concordia==1.6.0) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers->gdm-concordia==1.6.0) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers->gdm-concordia==1.6.0) (0.19.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->gdm-concordia==1.6.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->gdm-concordia==1.6.0) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->gdm-concordia==1.6.0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->gdm-concordia==1.6.0) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->gdm-concordia==1.6.0) (1.9.4)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai>=1.3.0->gdm-concordia==1.6.0) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai>=1.3.0->gdm-concordia==1.6.0) (1.2.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.10/dist-packages (from botocore<1.35.0,>=1.34.150->boto3->gdm-concordia==1.6.0) (2.0.7)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform->gdm-concordia==1.6.0) (1.63.2)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform->gdm-concordia==1.6.0) (1.64.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform->gdm-concordia==1.6.0) (1.48.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform->gdm-concordia==1.6.0) (5.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform->gdm-concordia==1.6.0) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform->gdm-concordia==1.6.0) (4.9)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform->gdm-concordia==1.6.0) (2.4.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform->gdm-concordia==1.6.0) (2.7.1)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /usr/local/lib/python3.10/dist-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform->gdm-concordia==1.6.0) (0.13.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai>=1.3.0->gdm-concordia==1.6.0) (2024.7.4)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai>=1.3.0->gdm-concordia==1.6.0)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.3.0->gdm-concordia==1.6.0)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers->gdm-concordia==1.6.0) (2024.6.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->gdm-concordia==1.6.0) (0.8.4)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.3.0,>=0.2.23->langchain->gdm-concordia==1.6.0)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->gdm-concordia==1.6.0) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->gdm-concordia==1.6.0) (0.2.13)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai>=1.3.0->gdm-concordia==1.6.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai>=1.3.0->gdm-concordia==1.6.0) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain->gdm-concordia==1.6.0) (3.3.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain->gdm-concordia==1.6.0) (3.0.3)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai->gdm-concordia==1.6.0) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai->gdm-concordia==1.6.0) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai->gdm-concordia==1.6.0) (4.1.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.10/dist-packages (from google-resumable-media<3.0dev,>=0.6.0->google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform->gdm-concordia==1.6.0) (1.5.0)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.23->langchain->gdm-concordia==1.6.0)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform->gdm-concordia==1.6.0) (0.6.0)
# Downloading openai-1.37.1-py3-none-any.whl (337 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 337.0/337.0 kB 10.1 MB/s eta 0:00:00
# Downloading pandas-2.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 86.2 MB/s eta 0:00:00
# Downloading boto3-1.34.150-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 11.6 MB/s eta 0:00:00
# Downloading langchain-0.2.11-py3-none-any.whl (990 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 990.3/990.3 kB 39.6 MB/s eta 0:00:00
# Downloading mistralai-0.4.2-py3-none-any.whl (20 kB)
# Downloading reactivex-4.0.4-py3-none-any.whl (217 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 217.8/217.8 kB 15.8 MB/s eta 0:00:00
# Downloading retry-0.9.2-py2.py3-none-any.whl (8.0 kB)
# Downloading botocore-1.34.150-py3-none-any.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 86.9 MB/s eta 0:00:00
# Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.9 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.4 MB/s eta 0:00:00
# Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 50.6 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading langchain_core-0.2.24-py3-none-any.whl (377 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.3/377.3 kB 24.6 MB/s eta 0:00:00
# Downloading langchain_text_splitters-0.2.2-py3-none-any.whl (25 kB)
# Downloading langsmith-0.1.94-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 11.5 MB/s eta 0:00:00
# Downloading orjson-3.10.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 12.9 MB/s eta 0:00:00
# Downloading py-1.11.0-py2.py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 kB 9.0 MB/s eta 0:00:00
# Downloading s3transfer-0.10.2-py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 kB 7.2 MB/s eta 0:00:00
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.1 MB/s eta 0:00:00
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Building wheels for collected packages: gdm-concordia
#   Building wheel for gdm-concordia (pyproject.toml) ... done
#   Created wheel for gdm-concordia: filename=gdm_concordia-1.6.0-py3-none-any.whl size=264150 sha256=d7c27ba08ac19e07199f8b51ccc6a37d502de709558f2c5b85dab8c9cd7eadc6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-dl5m6scg/wheels/a6/c2/be/c51d358b3afcea483f2da52be8072d9290e66f2d74174574b7
# Successfully built gdm-concordia
# Installing collected packages: py, orjson, jsonpointer, jmespath, h11, retry, reactivex, jsonpatch, jedi, httpcore, pandas, httpx, botocore, s3transfer, openai, mistralai, langsmith, langchain-core, boto3, langchain-text-splitters, langchain, gdm-concordia
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.4
#     Uninstalling pandas-2.1.4:
#       Successfully uninstalled pandas-2.1.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.1.4, but you have pandas 2.0.3 which is incompatible.
# Successfully installed boto3-1.34.150 botocore-1.34.150 gdm-concordia-1.6.0 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 jedi-0.19.1 jmespath-1.0.1 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.2.11 langchain-core-0.2.24 langchain-text-splitters-0.2.2 langsmith-0.1.94 mistralai-0.4.2 openai-1.37.1 orjson-3.10.6 pandas-2.0.3 py-1.11.0 reactivex-4.0.4 retry-0.9.2 s3transfer-0.10.2

# %%
# !pip install -r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt
# Out:
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: docstring-parser in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 2)) (0.16)
# Requirement already satisfied: gdm-concordia in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (1.6.0)
# Requirement already satisfied: IPython in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 4)) (7.34.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 5)) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 6)) (1.26.4)
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 7)) (1.37.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 8)) (2.0.3)
# Collecting sentence_transformers (from -r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9))
#   Using cached sentence_transformers-3.0.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 10)) (2.4.0)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.10/dist-packages (from gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (1.34.150)
# Requirement already satisfied: google-cloud-aiplatform in /usr/local/lib/python3.10/dist-packages (from gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (1.59.0)
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.10/dist-packages (from gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (0.7.2)
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (from gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (0.2.11)
# Requirement already satisfied: mistralai in /usr/local/lib/python3.10/dist-packages (from gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (0.4.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: reactivex in /usr/local/lib/python3.10/dist-packages (from gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (4.0.4)
# Requirement already satisfied: retry in /usr/local/lib/python3.10/dist-packages (from gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (0.9.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (1.13.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (4.42.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (4.12.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from IPython->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 4)) (71.0.4)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from IPython->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 4)) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from IPython->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 4)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from IPython->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 4)) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from IPython->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 4)) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from IPython->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 4)) (3.0.47)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from IPython->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 4)) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from IPython->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 4)) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from IPython->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 4)) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from IPython->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 4)) (4.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 5)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 5)) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 5)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 5)) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 5)) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 5)) (3.1.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 7)) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 7)) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 7)) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 7)) (2.8.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 7)) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 7)) (4.66.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 8)) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 8)) (2024.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9)) (2.3.1+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9)) (1.3.2)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9)) (0.23.5)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 7)) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 7)) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 7)) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 7)) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 7)) (0.14.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9)) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9)) (2024.6.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9)) (6.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9)) (2.31.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->IPython->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 4)) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->IPython->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 4)) (0.2.13)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 7)) (2.20.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9)) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9)) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9)) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.11.0->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9))
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.11.0->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9))
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.11.0->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9))
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.11.0->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9))
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.11.0->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9))
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.11.0->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9))
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.11.0->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9))
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.11.0->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9))
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.11.0->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9))
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.11.0->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9))
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.11.0->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9))
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9)) (2.3.1)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9))
#   Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (0.19.1)
# Requirement already satisfied: botocore<1.35.0,>=1.34.150 in /usr/local/lib/python3.10/dist-packages (from boto3->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (1.34.150)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from boto3->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from boto3->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (0.10.2)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (2.19.1)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (2.27.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (1.24.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (3.20.3)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (2.8.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (3.25.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (1.12.4)
# Requirement already satisfied: shapely<3.0.0dev in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (2.0.5)
# Requirement already satisfied: google-ai-generativelanguage==0.6.6 in /usr/local/lib/python3.10/dist-packages (from google-generativeai->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (0.6.6)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.10/dist-packages (from google-generativeai->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (2.137.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (4.0.3)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.23 in /usr/local/lib/python3.10/dist-packages (from langchain->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (0.2.24)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from langchain->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (0.2.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /usr/local/lib/python3.10/dist-packages (from langchain->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (0.1.94)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (8.5.0)
# Requirement already satisfied: orjson<3.11,>=3.9.10 in /usr/local/lib/python3.10/dist-packages (from mistralai->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (3.10.6)
# Requirement already satisfied: py<2.0.0,>=1.4.26 in /usr/local/lib/python3.10/dist-packages (from retry->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (1.11.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9)) (3.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (1.9.4)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.10/dist-packages (from botocore<1.35.0,>=1.34.150->boto3->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (2.0.7)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (1.63.2)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (1.64.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (1.48.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (5.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (4.9)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (2.4.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (2.7.1)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /usr/local/lib/python3.10/dist-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (0.13.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.23->langchain->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (1.33)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9)) (3.3.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (3.0.3)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (4.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9)) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9)) (1.3.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.10/dist-packages (from google-resumable-media<3.0dev,>=0.6.0->google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (1.5.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.23->langchain->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (3.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (0.6.0)
# Downloading sentence_transformers-3.0.1-py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 3.6 MB/s eta 0:00:00
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 22.9 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, sentence_transformers
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.82 nvidia-nvtx-cu12-12.1.105 sentence_transformers-3.0.1

# %%
import os
import random
import datetime
import numpy as np
import concurrent.futures
import sentence_transformers
import matplotlib.pyplot as plt
import collections

from typing import Callable
from IPython import display

from concordia.utils import plotting
from concordia.clocks import game_clock
from concordia.agents import basic_agent
from concordia.utils import html as html_lib
from concordia.environment import game_master
from concordia.language_model import gpt_model
from concordia.language_model import mistral_model
from concordia.document import interactive_document
from concordia.components import agent as components
from concordia import components as generic_components
from concordia.associative_memory import blank_memories
from concordia.components import agent as agent_components
from concordia.components import agent as components
from concordia.factory.environment import basic_game_master
from concordia.associative_memory import associative_memory
from concordia.associative_memory import formative_memories
from concordia.associative_memory import importance_function
from concordia.utils import measurements as measurements_lib
from concordia.components import game_master as gm_components
from concordia.thought_chains import thought_chains as thought_chains_lib
from concordia.environment.scenes import conversation as conversation_scene
from concordia.metrics import goal_achievement
from concordia.metrics import common_sense_morality
from concordia.metrics import opinion_of_others

# %% [markdown]
# ### Sentence Encoder Setup

# %%
st_model = sentence_transformers.SentenceTransformer(
    'sentence-transformers/all-mpnet-base-v2')
embedder = lambda x: st_model.encode(x, show_progress_bar=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# ### Language Model Initialization

# %%
mistral_api_key = 'aOK3ra58cBpuMSrXSQkRjF4xX6kJYdaL'
if not mistral_api_key:
      raise ValueError('Mistral api_key is required.')
model = mistral_model.MistralLanguageModel(api_key=mistral_api_key,
                                           model_name='codestral-latest')

# %% [markdown]
# ## Configuring the generic knowledge of players and GM

# %%
# Define all the characters of the environment
CHARACTERS = ['Alice', 'David', 'Emma', 'Michael']
WHO_SPREADS_NEWS = np.random.choice(CHARACTERS)

# Define the fake news
FAKE_NEWS = "First Manned Mission to Mars Scheduled for Next Month!"

shared_memory = [
    f' You are having a casual conversation with some friends when {WHO_SPREADS_NEWS} suddenly'
    f' shares a surprising piece of news: "{FAKE_NEWS}". Then all of you discuss whether the news'
    ' is true or false, evaluating the information based on your knowledge, the'
    ' credibility of the source, and any verification tools you have. This setting'
    ' provides a realistic scenario for observing the spread of fake news and testing'
    ' strategies to prevent it.'
]

# Context that all characters and GM share
shared_context = model.sample_text(
    'Summarize the following passage in a concise and insightful fashion:\n'
    + '\n'.join(shared_memory)
    + '\n'
    + 'Summary:'
)
print(shared_context)

importance_model = importance_function.ConstantImportanceModel()
importance_model_gm = importance_function.ConstantImportanceModel()
# Out:
# In a casual conversation, Alice announces a surprising news about the first manned mission to Mars scheduled for the next month. The group discusses the news's authenticity, relying on their knowledge, the source's credibility, and any available verification tools, highlighting a practical situation for examining the spread of false information and devising countermeasures.

# %% [markdown]
# ### Make the clock

# %%
UPDATE_INTERVAL = datetime.timedelta(seconds=10)

SETUP_TIME = datetime.datetime(hour=8, year=2024, month=6, day=1)

START_TIME = datetime.datetime(hour=14, year=2024, month=7, day=1)
clock = game_clock.MultiIntervalClock(
    start=SETUP_TIME,
    step_sizes=[UPDATE_INTERVAL, datetime.timedelta(seconds=10)])

NUM_ROUNDS = 3

# %% [markdown]
# ## Functions to build the agents

# %% [markdown]
# It might be convenient to highlight the difference between a **blank memory** and a **formative memory**:
#
# * Blank memory: refers to a state where no prior information or data is stored (essentially an empty memory state).
# * Formative memory: consists of past experiences and information that shape the current state of the agent (it includes all the data that the agent has acquired and learned from over time).

# %%
blank_memory_factory = blank_memories.MemoryFactory(
    model=model,
    embedder=embedder,
    importance=importance_model.importance,
    clock_now=clock.now,
)

formative_memory_factory = formative_memories.FormativeMemoryFactory(
    model=model,
    blank_memory_factory_call=blank_memory_factory.make_blank_memory,
)

# %%
def build_agent(agent_config,
                player_names: list[str],
                measurements: measurements_lib.Measurements | None = None):

  mem = formative_memory_factory.make_memories(agent_config)

  agent_name = agent_config.name
  instructions = generic_components.constant.ConstantComponent(
      state=(
          f'The instructions for how to play the role of {agent_name} are as '
          'follows. This is a social science experiment studying how well you '
          f'play the role of a character named {agent_name}. The experiment '
          'is structured as a tabletop roleplaying game (like dungeons and '
          'dragons). However, in this case it is a serious social science '
          'experiment and simulation. The goal is to be realistic. It is '
          f'important to play the role of a person like {agent_name} as '
          f'accurately as possible, i.e., by responding in ways that you think '
          f'it is likely a person like {agent_name} would respond, and taking '
          f'into account all information about {agent_name} that you have. '
          'Always use third-person limited perspective.'
      ),
      name='role playing instructions\n')

  if agent_config.extras.get('spreads news', False):
    fact = generic_components.constant.ConstantComponent(
        state=f'{agent_name} spreads the fake news: "{FAKE_NEWS}"', name='fact')
  else:
    fact = generic_components.constant.ConstantComponent(
        state=f'{agent_name} tries to check the veracity of the news.', name='fact')

  time = generic_components.report_function.ReportFunction(
      name='Current time',
      function=clock.current_time_interval_str,
  )

  current_obs = components.observation.Observation(
            agent_name=agent_config.name,
      clock_now=clock.now,
      memory=mem,
      timeframe=clock.get_step_size(),
      component_name='current observations',
  )
  somatic_state = components.somatic_state.SomaticState(
      model=model,
      memory=mem,
      agent_name=agent_config.name,
      clock_now=clock.now,
  )
  summary_obs = components.observation.ObservationSummary(
      agent_name=agent_config.name,
      model=model,
      clock_now=clock.now,
      memory=mem,
      components=[current_obs],
      timeframe_delta_from=datetime.timedelta(hours=4),
      timeframe_delta_until=datetime.timedelta(hours=1),
      component_name='summary of observations',
  )

  self_perception = components.self_perception.SelfPerception(
      name=f'answer to what kind of person is {agent_config.name}',
      model=model,
      memory=mem,
      agent_name=agent_config.name,
      clock_now=clock.now,
  )
  relevant_memories = components.all_similar_memories.AllSimilarMemories(
      name='relevant memories',
      model=model,
      memory=mem,
      agent_name=agent_name,
      components=[summary_obs, self_perception],
      clock_now=clock.now,
      num_memories_to_retrieve=25,
      verbose=False,
  )
  situation_perception = components.situation_perception.SituationPerception(
      name=(f'answer to what kind of situation is {agent_config.name} in ' +
            'right now'),
      model=model,
      memory=mem,
      agent_name=agent_config.name,
      components=[current_obs, somatic_state, summary_obs],
      clock_now=clock.now,
  )
  person_by_situation = components.person_by_situation.PersonBySituation(
      name=(f'answer to what would a person like {agent_config.name} do in a ' +
            'situation like this'),
      model=model,
      memory=mem,
      agent_name=agent_config.name,
      clock_now=clock.now,
      components=[self_perception, situation_perception],
      verbose=True,
  )

  persona = generic_components.sequential.Sequential(
      name='persona',
      components=[
          self_perception,
          situation_perception,
          person_by_situation,
      ]
  )

  justification_components = components.justify_recent_voluntary_actions
  justification = justification_components.JustifyRecentVoluntaryActions(
      name='justification',
      model=model,
      memory=mem,
      agent_name=agent_config.name,
      components=[persona, somatic_state, relevant_memories],
      clock_now=clock.now,
      verbose=True,
  )
  reflection = components.dialectical_reflection.DialecticalReflection(
      name='reflection',
      model=model,
      memory=mem,
      agent_name=agent_config.name,
      intuition_components=[self_perception, justification],
      thinking_components=[persona],
      clock_now=clock.now,
      num_memories_to_retrieve=5,
      verbose=True,
  )

  initial_goal_component = generic_components.constant.ConstantComponent(
      state=agent_config.goal, name='overarching goal')
  plan = components.plan.SimPlan(
      model,
      mem,
      agent_config.name,
      clock_now=clock.now,
      components=[instructions,
                  fact,
                  initial_goal_component,
                  relevant_memories,
                  persona,
                  justification],
      goal=person_by_situation,
      horizon='the next hour',
      verbose=True,
  )

  goal_metric = goal_achievement.GoalAchievementMetric(
      model=model,
      player_name=agent_config.name,
      player_goal=agent_config.goal,
      clock=clock,
      name='Goal Achievement',
      measurements=measurements,
      channel='goal_achievement',
      verbose=False,
  )
  morality_metric = common_sense_morality.CommonSenseMoralityMetric(
      model=model,
      player_name=agent_config.name,
      clock=clock,
      name='Morality',
      verbose=False,
      measurements=measurements,
      channel='common_sense_morality',
  )
  agent = basic_agent.BasicAgent(
      model,
      agent_name=agent_config.name,
      clock=clock,
      verbose=True,
      components=[instructions,
                  fact,
                  persona,
                  justification,
                  reflection,
                  plan,
                  time,
                  relevant_memories,
                  current_obs,
                  goal_metric,
                  morality_metric],
      update_interval = UPDATE_INTERVAL
  )
  reputation_metric = opinion_of_others.OpinionOfOthersMetric(
      model=model,
      player_name=agent_config.name,
      player_names=player_names,
      context_fn=agent.state,
      clock=clock,
      name='Opinion',
      verbose=False,
      measurements=measurements,
      channel='opinion_of_others',
      question='What is {opining_player}\'s opinion of {of_player}?',
  )
  agent.add_component(reputation_metric)
  return agent, mem

# %% [markdown]
# ## Configure and build the agents

# %%
# Define a function to generate random traits for an agent
TRAIT_LEVELS = ["low", "medium", "high"] # range of possible levels for traits

def make_random_traits() -> str:
  return str({
      "extraversion": np.random.choice(TRAIT_LEVELS),
      "neuroticism": np.random.choice(TRAIT_LEVELS),
      "openness": np.random.choice(TRAIT_LEVELS),
      "conscientiousness": np.random.choice(TRAIT_LEVELS),
      "agreeableness": np.random.choice(TRAIT_LEVELS),
      "susceptibility": np.random.choice(TRAIT_LEVELS),
      "critical thinking": np.random.choice(TRAIT_LEVELS),
  })


# Create player configurations, each represented by an AgentConfig object
player_configs = [
    formative_memories.AgentConfig(
        name=CHARACTERS[0],
        gender='female',
        goal=f"Figure out if the news spread by {WHO_SPREADS_NEWS} are true or not",
        #context=(motives[WHO_FOUND_BODY] + ' ' +
        #        motives_to_investigate[WHO_FOUND_BODY] + ' ' +
        #         knowledge_of_scandal.get(WHO_FOUND_BODY, '')),
        traits = make_random_traits(),
        formative_ages = sorted(random.sample(range(5, 40), 5)),
        extras={'spreads news': CHARACTERS[0] == WHO_SPREADS_NEWS,
                'political_ideology': 'liberal'},
    ),
    formative_memories.AgentConfig(
        name=CHARACTERS[1],
        gender='male',
        goal=f"Figure out if the news spread by {WHO_SPREADS_NEWS} are true or not",
        #context=(motives[WHO_FOUND_BODY] + ' ' +
        #        motives_to_investigate[WHO_FOUND_BODY] + ' ' +
        #         knowledge_of_scandal.get(WHO_FOUND_BODY, '')),
        traits = make_random_traits(),
        formative_ages = sorted(random.sample(range(5, 40), 5)),
        extras={'spreads news': CHARACTERS[1] == WHO_SPREADS_NEWS,
                'political_ideology': 'conservative'},
    ),
    formative_memories.AgentConfig(
        name=CHARACTERS[2],
        gender='female',
        goal=f"Figure out if the news spread by {WHO_SPREADS_NEWS} are true or not",
        #context=(motives[WHO_FOUND_BODY] + ' ' +
        #        motives_to_investigate[WHO_FOUND_BODY] + ' ' +
        #         knowledge_of_scandal.get(WHO_FOUND_BODY, '')),
        traits = make_random_traits(),
        formative_ages = sorted(random.sample(range(5, 40), 5)),
        extras={'spreads news': CHARACTERS[2] == WHO_SPREADS_NEWS,
                'political_ideology': 'moderate'},
    ),
    formative_memories.AgentConfig(
        name=CHARACTERS[3],
        gender='male',
        goal=f"Figure out if the news spread by {WHO_SPREADS_NEWS} are true or not",
        #context=(motives[WHO_FOUND_BODY] + ' ' +
        #        motives_to_investigate[WHO_FOUND_BODY] + ' ' +
        #         knowledge_of_scandal.get(WHO_FOUND_BODY, '')),
        traits = make_random_traits(),
        formative_ages = sorted(random.sample(range(5, 40), 5)),
        extras={'spreads news': CHARACTERS[3] == WHO_SPREADS_NEWS,
                'political_ideology': 'libertarian'},
    ),
]

# %%
NUM_PLAYERS = len(player_configs)
player_names = [player.name for player in player_configs][:NUM_PLAYERS]
measurements = measurements_lib.Measurements()

players = []
memories = {}
with concurrent.futures.ThreadPoolExecutor(max_workers=NUM_PLAYERS) as pool:
  for agent, mem in pool.map(build_agent,
                             player_configs[:NUM_PLAYERS],
                             # All players get the same `player_names`.
                             [player_names] * NUM_PLAYERS,
                             # All players get the same `measurements` object.
                             [measurements] * NUM_PLAYERS):
    players.append(agent)
    memories[agent.name] = mem
# Out:
# Memories of Alice:
# [03 Jul 1991 00:00:00] 1. When Alice was 7 years old, they lost their beloved pet cat, Whiskers, in a tragic accident. This event taught Alice the importance of responsibility and empathy, values that would shape her life.
# [03 Jul 1998 00:00:00] 2. At age 14, Alice discovered a hidden room in their family home. Inside, she found a collection of ancient books and a mysterious key. This discovery sparked her lifelong love for reading and solving puzzles.
# [03 Jul 2000 00:00:00] 3. When Alice was 16, she volunteered at a local library and met Emily, her future sister-in-law. Their shared love for books and puzzles led to a deep friendship that would last a lifetime.
# [03 Jul 2002 00:00:00] 4. At age 18, Alice faced a difficult decision: should she pursue a career in academia or follow her heart and become a librarian? After careful consideration, she chose the latter, knowing it would allow her to use her skills and help others.
# [03 Jul 2018 00:00:00] 5. When Alice was 34, her father passed away unexpectedly.
# [01 Jun 2024 08:00:00] Figure out if the news spread by Alice are true or not
# [01 Jun 2024 08:00:00] [self reflection] Alice is 34 years old in the year 2018, a librarian, and a person who values responsibility, empathy, and a love for reading and solving puzzles. She has a strong friendship with Emily. In the year 2002, she faced a significant decision between pursuing a career in academia and becoming a librarian, ultimately choosing the latter. In 2018, she experienced the loss of her father.
# ***
# Current time: 2024-06-01 08:00:00
# Alice's answer to what kind of person is Alice:
# Alice is 34 years old in the year 2018, a librarian, and a person who values responsibility, empathy, and a love for reading and solving puzzles. She has a strong friendship with Emily. In the year 2002, she faced a significant decision between pursuing a career in academia and becoming a librarian, ultimately choosing the latter. In 2018, she experienced the loss of her father.
# Alice's answer to what kind of situation is Alice in right now:
#
# Question: What would a person like Alice do in a situation like this?
# Answer: Alice would 1) remain calm and composed, 2) carefully evaluate the information provided in the news articles, 3) consider the potential consequences of spreading false information, and 4) make a decision based on the facts and her values of responsibility and truthfulness.
# Memories of David:
# [03 Jul 1992 00:00:00] 1. When David was 8 years old, they experienced a sudden move to a new neighborhood, which forced them to make new friends and navigate unfamiliar surroundings. This event challenged their neuroticism, as they had to face the fear of the unknown, but also fostered their openness and adaptability.
# [03 Jul 1999 00:00:00] 2. At 15, David's passion for music was ignited when he discovered a guitar in their uncle's attic. Despite their initial fear of failure, they persevered and learned to play, discovering a newfound confidence and outlet for their emotions.
# [03 Jul 2007 00:00:00] 3. At 23, David joined a startup as a software engineer, where they encountered a major project failure. This event tested their critical thinking and resilience, and they learned the importance of self-reflection and continuous learning.
# [03 Jul 2016 00:00:00] 4. At 32, David embarked on a solo backpacking trip to Europe, pushing their boundaries and confronting their fears of abandonment and rejection. This transformative experience allowed them to grow in self-reliance and self-discovery.
# [03 Jul 2022 00:00:00] 5. At 38, David's mentor retired, leaving a gap in their professional life.
# [01 Jun 2024 08:00:00] Figure out if the news spread by Alice are true or not
# [03 Jul 2000 00:00:00] 3. When Alice was 16, she volunteered at a local library and met Emily, her future sister-in-law. Their shared love for books and puzzles led to a deep friendship that would last a lifetime.
# [03 Jul 2002 00:00:00] 4. At age 18, Alice faced a difficult decision: should she pursue a career in academia or follow her heart and become a librarian? After careful consideration, she chose the latter, knowing it would allow her to use her skills and help others.
# [03 Jul 2018 00:00:00] 5. When Alice was 34, her father passed away unexpectedly.
# [01 Jun 2024 08:00:00] Figure out if the news spread by Alice are true or not
# [01 Jun 2024 08:00:00] [self reflection] Alice is 34 years old in the year 2018, a librarian, and a person who values responsibility, empathy, and a love for reading and solving puzzles. She has a strong friendship with Emily. In the year 2002, she faced a significant decision between pursuing a career in academia and becoming a librarian, ultimately choosing the latter. In 2018, she experienced the loss of her father.
# [01 Jun 2024 08:00:00] [intent reflection] Alice would 1) remain calm and composed, 2) carefully evaluate the information provided in the news articles, 3) consider the potential consequences of spreading false information, and 4) make a decision based on the facts and her values of responsibility and truthfulness.
# The current time: 2024-06-01 08:00:00.
# Question: Summarize the gist of Alice's most recent voluntary actions. Do not speculate about their motives. Just straightforwardly describe what they did most recently.
# Answer:  Alice recently experienced the loss of her father, which is the most significant event that has occurred in her life recently. She has not taken any new voluntary actions since then that can be described.
# Question: If any, what consequences did Alice's most recent voluntary actions have? Only consider effects that have already occurred (before 2024-06-01 08:00:00).
# Answer:  Alice's most recent voluntary action was experiencing the loss of her father. This event had significant consequences, including emotional distress, the need to manage her father's estate, and the potential for changes in her personal and professional life. However, since the current time is before 2024-06-01 08:00:00, we cannot know the specific consequences Alice has faced as a result of this event.
# Alice's persona:
#
# answer to what kind of person is Alice: Alice is 34 years old in the year 2018, a librarian, and a person who values responsibility, empathy, and a love for reading and solving puzzles. She has a strong friendship with Emily. In the year 2002, she faced a significant decision between pursuing a career in academia and becoming a librarian, ultimately choosing the latter. In 2018, she experienced the loss of her father.
# answer to what would a person like Alice do in a situation like this: Alice would 1) remain calm and composed, 2) carefully evaluate the information provided in the news articles, 3) consider the potential consequences of spreading false information, and 4) make a decision based on the facts and her values of responsibility and truthfulness.
# Alice's Somatic state:
#
# Alice's relevant memories:
# 1. [03 Jul 1991 00:00:00] Alice lost their beloved pet cat, Whiskers, in a tragic accident when they were 7 years old. This event shaped her values of responsibility and empathy.
# 2. [03 Jul 1998 00:00:00] Alice discovered a hidden room in their family home at age 14, finding ancient books and a mysterious key. This discovery sparked her lifelong love for reading and solving puzzles.
# 3. [03 Jul 2000 00:00:00] Alice met Emily, her future sister-in-law, at age 16 while volunteering at a local library. Their shared love for books and puzzles formed a deep friendship.
# 4. [03 Jul 2002 00:00:00] Alice made a significant decision at age 18 between pursuing a career in academia and becoming a librarian, ultimately choosing the latter.
# 5. [03 Jul 2018 00:00:00] Alice experienced the loss of her father when she was 34 years old.
# The current time: 2024-06-01 08:00:00.
# Alice's latest voluntary action:  Alice recently experienced the loss of her father, which is the most significant event that has occurred in her life recently. She has not taken any new voluntary actions since then that can be described.
# Answer: Alice  would most likely prioritize justifying her actions to her closest circles, such as her spouse, friends, and family members, as well as her professional peers and superiors. In this context, she would emphasize the importance of evaluating information carefully, making decisions based on facts, and acting in the best interests of those affected. She would also acknowledge the emotional impact of the situation and seek support as needed.
#
# Alice's role playing instructions
# :
# The instructions for how to play the role of Alice are as follows. This is a social science experiment studying how well you play the role of a character named Alice. The experiment is structured as a tabletop roleplaying game (like dungeons and dragons). However, in this case it is a serious social science experiment and simulation. The goal is to be realistic. It is important to play the role of a person like Alice as accurately as possible, i.e., by responding in ways that you think it is likely a person like Alice would respond, and taking into account all information about Alice that you have. Always use third-person limited perspective.
# Alice's fact:
# Alice spreads the fake news: "First Manned Mission to Mars Scheduled for Next Month!"
# Alice's overarching goal:
# Figure out if the news spread by Alice are true or not
# Alice's relevant memories:
# 1. [03 Jul 1991 00:00:00] Alice lost their beloved pet cat, Whiskers, in a tragic accident when they were 7 years old. This event shaped her values of responsibility and empathy.
# 2. [03 Jul 1998 00:00:00] Alice discovered a hidden room in their family home at age 14, finding ancient books and a mysterious key. This discovery sparked her lifelong love for reading and solving puzzles.
# 3. [03 Jul 2000 00:00:00] Alice met Emily, her future sister-in-law, at age 16 while volunteering at a local library. Their shared love for books and puzzles formed a deep friendship.
# 4. [03 Jul 2002 00:00:00] Alice made a significant decision at age 18 between pursuing a career in academia and becoming a librarian, ultimately choosing the latter.
# 5. [03 Jul 2018 00:00:00] Alice experienced the loss of her father when she was 34 years old.
# Alice's persona:
#
# answer to what kind of person is Alice: Alice is 34 years old in the year 2018, a librarian, and a person who values responsibility, empathy, and a love for reading and solving puzzles. She has a strong friendship with Emily. In the year 2002, she faced a significant decision between pursuing a career in academia and becoming a librarian, ultimately choosing the latter. In 2018, she experienced the loss of her father.
# answer to what would a person like Alice do in a situation like this: Alice would 1) remain calm and composed, 2) carefully evaluate the information provided in the news articles, 3) consider the potential consequences of spreading false information, and 4) make a decision based on the facts and her values of responsibility and truthfulness.
# Alice's justification:
# [thought] Alice  would most likely prioritize justifying her actions to her closest circles, such as her spouse, friends, and family members, as well as her professional peers and superiors. In this context, she would emphasize the importance of evaluating information carefully, making decisions based on facts, and acting in the best interests of those affected. She would also acknowledge the emotional impact of the situation and seek support as needed.
#
# Relevant memories:
# [03 Jul 1991 00:00:00] 1. When Alice was 7 years old, they lost their beloved pet cat, Whiskers, in a tragic accident. This event taught Alice the importance of responsibility and empathy, values that would shape her life.
# [01 Jun 2024 08:00:00] [intent reflection] Alice would 1) remain calm and composed, 2) carefully evaluate the information provided in the news articles, 3) consider the potential consequences of spreading false information, and 4) make a decision based on the facts and her values of responsibility and truthfulness.
# [01 Jun 2024 08:00:00] [self reflection] Alice is 34 years old in the year 2018, a librarian, and a person who values responsibility, empathy, and a love for reading and solving puzzles. She has a strong friendship with Emily. In the year 2002, she faced a significant decision between pursuing a career in academia and becoming a librarian, ultimately choosing the latter. In 2018, she experienced the loss of her father.
# [01 Jun 2024 08:00:00] Figure out if the news spread by Alice are true or not
# [01 Jun 2024 08:00:00] [intent reflection] Emma would 1) carefully evaluate the information presented by the renowned scientist at the climate change conference and 2) consider the potential impact on society and the environment. Based on that evaluation, Emma would likely 3) advocate for policies and initiatives that prioritize sustainable practices and promote renewable energy sources. She might also 4) seek out opportunities to collaborate with other experts and organizations in the field to further advance scientific understanding and promote positive change. Ultimately, Emma's actions would be guided by her commitment to environmental science and her desire to make a positive impact on the world.
# [01 Jun 2024 08:00:00] Figure out if the news spread by Alice are true or not
# Current goal: Emma would 1) carefully evaluate the information presented by the renowned scientist at the climate change conference and 2) consider the potential impact on society and the environment. Based on that evaluation, Emma would likely 3) advocate for policies and initiatives that prioritize sustainable practices and promote renewable energy sources. She might also 4) seek out opportunities to collaborate with other experts and organizations in the field to further advance scientific understanding and promote positive change. Ultimately, Emma's actions would be guided by her commitment to environmental science and her desire to make a positive impact on the world..
# Current plan:
# Current situation:
# The current time is: [01 Jun 2024 08:00:00]
#
# Question: Given the above, should Emma change their current plan?
#   (a) Yes
#   (b) No
# Answer: (a)
# Question: Write Emma's plan for the next hour. Please, provide a detailed schedule, keep in mind the goal. Please format the plan like in this example: [21:00 - 22:00] watch TV
# Answer: 1) [08:00 - 08:30] Review the information presented by the renowned scientist at the climate change conference.
# 2) [08:30 - 09:00] Conduct a preliminary assessment of the potential impact on society and the environment.
# 3) [09:00 - 09:30] Research and gather data on existing policies and initiatives related to sustainable practices and renewable energy sources.
# 4) [09:30 - 10:00] Evaluate the effectiveness and feasibility of these policies and initiatives.
# 5) [10:00 - 10:30] Brainstorm potential new policies and initiatives that could further promote sustainable practices and renewable energy sources.
# 6) [10:30 - 11:00] Identify potential collaborators and organizations in the field that could help advance scientific understanding and promote positive change.
# 7) [11:00 - 11:30] Prepare a report summarizing findings and recommendations.
# 8) [11:30 - 12:00] Evaluate the news spread by Alice and determine its authenticity and relevance to the current situation.
# 9) [12:00 - 12:30] If the news is relevant and authentic, consider its implications for Emma's current plan and make any necessary adjustments.
# 10) [12:30 - 13:00] Review and finalize the report, ensuring that it accurately reflects Emma's evaluation of the information presented by the renowned scientist at the climate change conference and the potential impact on society and the environment.
# Emma's plan for the next hour:
# [08:00 - 08:30] Review the information presented by the renowned scientist at the climate change conference.
#
#
# Michael's role playing instructions
# :
# The instructions for how to play the role of Michael are as follows. This is a social science experiment studying how well you play the role of a character named Michael. The experiment is structured as a tabletop roleplaying game (like dungeons and dragons). However, in this case it is a serious social science experiment and simulation. The goal is to be realistic. It is important to play the role of a person like Michael as accurately as possible, i.e., by responding in ways that you think it is likely a person like Michael would respond, and taking into account all information about Michael that you have. Always use third-person limited perspective.
# Michael's fact:
# Michael tries to check the veracity of the news.
# Michael's overarching goal:
# Figure out if the news spread by Alice are true or not
# Michael's relevant memories:
# 1. [03 Jul 1994 00:00:00] Michael's early success in a coding competition boosted their confidence and fueled their passion for learning.
# 3. [03 Jul 2010 00:00:00] Michael's experience with a significant project failure strengthened their resilience and determination.
# 4. [03 Jul 2013 00:00:00] Michael's organization of a charity event reinforced their belief in making a positive impact and their commitment to helping others.
# 5. [03 Jul 2020 00:00:00] Michael's mentoring experience with a junior engineer, Sarah, demonstrates their ability to support and guide others in their career.
# [01 Jun 2024 08:00:00] Michael should 1) carefully evaluate and analyze the information provided by Alice, 2) seek additional information and clarification if necessary, and 3) consider the potential impact of the news on their own career and reputation.
# Michael's persona:
#
# answer to what kind of person is Michael: Michael is 36 in 2024. They are a software engineer who has experienced significant successes, such as winning a coding competition as a teenager and organizing a charity event. They have also faced challenges, such as a project failure. Michael has demonstrated resilience, critical thinking skills, and a commitment to helping others. They have also served as a mentor to both a senior engineer and a junior engineer, demonstrating their ability to support and guide others in their career.
# answer to what kind of situation is Michael in right now: Michael is currently 36 years old and has been actively mentoring a young software engineer named Sarah. There is no recent information about Michael's professional or personal life to indicate any changes in their situation.
# answer to what would a person like Michael do in a situation like this: Michael would 1) carefully evaluate and analyze the information provided by Alice, 2) seek additional information and clarification if necessary, 3) consider the potential impact of the news on their own career and reputation, 4) weigh the potential risks and benefits of taking action, and 5) make a decision that is aligned with their values and goals.
# Michael's justification:
#
#
# Relevant memories:
# [03 Jul 1994 00:00:00] 1. When Michael was 10 years old, they experienced a coding competition that challenged their critical thinking skills. They emerged as the winner, boosting their confidence and fueling their passion for learning.
# [03 Jul 2013 00:00:00] 4. At age 29, Michael organized a charity event to raise funds for a local children's hospital. The experience reinforced their belief in making a positive impact and their commitment to helping others.
# [01 Jun 2024 08:00:00] [self reflection] Michael is 36 in 2024. They are a software engineer who has experienced significant successes, such as winning a coding competition as a teenager and organizing a charity event. They have also faced challenges, such as a project failure. Michael has demonstrated resilience, critical thinking skills, and a commitment to helping others. They have also served as a mentor to both a senior engineer and a junior engineer, demonstrating their ability to support and guide others in their career.
# [01 Jun 2024 08:00:00] [intent reflection] Michael would 1) carefully evaluate and analyze the information provided by Alice, 2) seek additional information and clarification if necessary, 3) consider the potential impact of the news on their own career and reputation, 4) weigh the potential risks and benefits of taking action, and 5) make a decision that is aligned with their values and goals.
# [01 Jun 2024 08:00:00] Figure out if the news spread by Alice are true or not
# [03 Jul 2005 00:00:00] 2. At age 21, Michael had a mentoring relationship with a senior software engineer, John. John's guidance and support helped Michael navigate the complexities of the industry and solidify his career path.
# [03 Jul 2013 00:00:00] 4. At age 29, Michael organized a charity event to raise funds for a local children's hospital. The experience reinforced their belief in making a positive impact and their commitment to helping others.
# [01 Jun 2024 08:00:00] [intent reflection] Michael would 1) carefully evaluate and analyze the information provided by Alice, 2) seek additional information and clarification if necessary, 3) consider the potential impact of the news on their own career and reputation, 4) weigh the potential risks and benefits of taking action, and 5) make a decision that is aligned with their values and goals.
# [01 Jun 2024 08:00:00] Figure out if the news spread by Alice are true or not
# [01 Jun 2024 08:00:00] [self reflection] Michael is 36 in 2024. They are a software engineer who has experienced significant successes, such as winning a coding competition as a teenager and organizing a charity event. They have also faced challenges, such as a project failure. Michael has demonstrated resilience, critical thinking skills, and a commitment to helping others. They have also served as a mentor to both a senior engineer and a junior engineer, demonstrating their ability to support and guide others in their career.
# Current goal: Michael would 1) carefully evaluate and analyze the information provided by Alice, 2) seek additional information and clarification if necessary, 3) consider the potential impact of the news on their own career and reputation, 4) weigh the potential risks and benefits of taking action, and 5) make a decision that is aligned with their values and goals..
# Answer: Michael may synthesize the thesis and antithesis to form a new perspective that acknowledges the complexity and nuance of their experiences and contributions, and recognizes the need for continued self-reflection and growth. For example, they may acknowledge that while their coding competition success and project failure were significant experiences, they may have learned valuable lessons from both events and that their personal and professional growth has been ongoing. They may also acknowledge that while their mentoring relationship with Sarah has been beneficial, there may be areas for improvement and that they can continue to learn and grow as a mentor.
# Question: How would Michael synthesize the thesis with its antithesis in a novel and insightful way?
# Answer: Michael would think step by step, and start by pointing out that 1) their experiences and contributions are complex and multifaceted, 2) they have learned and grown from both positive and negative experiences, and 3) they are committed to continuous self-reflection and improvement. They may then emphasize the importance of recognizing and learning from both successes and failures, and the value of ongoing growth and development. They may also acknowledge the role of context and perspective in shaping experiences, and the need to consider multiple perspectives when making decisions.
# Question: What advice would Michael give to Alice about how to handle the situation?
# Answer: Michael would advise Alice to 1) carefully evaluate and analyze the information provided, 2) seek additional information and clarification if necessary, 3) consider the potential impact of the news on their own career and reputation, 4) weigh the potential risks and benefits of taking action, and 5) make a decision that is aligned with their values and goals. Michael may also suggest that Alice seek out a neutral third party to help them evaluate the situation and provide objective advice, if possible. Ultimately, Michael would encourage Alice to approach the situation with a calm and rational mindset, and to make decisions that are based on a thorough understanding of the facts and their own values and goals.
# Question: How might Michael summarize the synthesis above as a bold new argument?
# Answer: In Michael's view, the full argument is complex but the TLDR is that 1) individuals' experiences and contributions are multifaceted and shaped by a variety of factors, 2) it is important to learn and grow from both positive and negative experiences, and 3) making informed decisions requires a careful evaluation of the facts and a consideration of one's own values and goals. Michael's bold new argument is that individuals should embrace the complexity and nuance of their experiences, and approach decision-making with a commitment to continuous self-reflection, critical thinking, and a focus on their own values and goals.

# %% [markdown]
# ### Summarise the perspective of each player

# %%
player_logs = []
player_log_names = []
for player in players:
  name = player.name
  detailed_story = '\n'.join(memories[player.name].retrieve_recent(
      k=1000, add_time=True))
  summary = player.state().splitlines()

  all_player_mem = memories[player.name].retrieve_recent(k=1000, add_time=True)
  all_player_mem = ['Player state:', summary, 'Memories:'] + all_player_mem
  player_html = html_lib.PythonObjectToHTMLConverter(all_player_mem).convert()
  player_logs.append(player_html)
  player_log_names.append(f'{name}')

tabbed_html = html_lib.combine_html_pages(
    player_logs,
    player_log_names,
    summary='',
    title='Backstory of the players',
)

tabbed_html = html_lib.finalise_html(tabbed_html)
display.HTML(tabbed_html)
# Out:
#   <!DOCTYPE html>
#   <html>
#   <head>
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <style>
#   body {font-family: Arial;}
#
#   /* Style the tab */
#   .tab {
#     overflow: hidden;
#     border: 1px solid #ccc;
#     background-color: #f1f1f1;
#   }
#
#   /* Style the buttons inside the tab */
#   .tab button {
#     background-color: inherit;
#     float: left;
#     border: none;
#     outline: none;
#     cursor: pointer;
#     padding: 14px 16px;
#     transition: 0.3s;
#     font-size: 17px;
#   }
#
#   /* Change background color of buttons on hover */
#   .tab button:hover {
#     background-color: #ddd;
#   }
#
#   /* Create an active/current tablink class */
#   .tab button.active {
#     background-color: #ccc;
#   }
#
#   /* Style the tab content */
#   .tabcontent {
#     display: none;
#     padding: 6px 12px;
#     border: 1px solid #ccc;
#     border-top: none;
#   }
#   li {border: 2px solid black;}
#   </style>
#   </head>
#   <body>
#   <h2>Backstory of the players</h2>
#   <p></p>
#   <p>Click on the buttons to see the detailed logs:</p>
#
#   <div class="tab">
#   <button class="tablinks" onclick="openTab(event, 'Alice')">Alice</button>
# <button class="tablinks" onclick="openTab(event, 'David')">David</button>
# <button class="tablinks" onclick="openTab(event, 'Emma')">Emma</button>
# <button class="tablinks" onclick="openTab(event, 'Michael')">Michael</button>
# </div>
# <div id="Alice" class="tabcontent">Player state:<br />Alice&#x27;s role playing instructions<br />:<br />The instructions for how to play the role of Alice are as follows. This is a social science experiment studying how well you play the role of a character named Alice. The experiment is structured as a tabletop roleplaying game (like dungeons and dragons). However, in this case it is a serious social science experiment and simulation. The goal is to be realistic. It is important to play the role of a person like Alice as accurately as possible, i.e., by responding in ways that you think it is likely a person like Alice would respond, and taking into account all information about Alice that you have. Always use third-person limited perspective.<br /><br />Alice&#x27;s fact:<br />Alice spreads the fake news: &quot;First Manned Mission to Mars Scheduled for Next Month!&quot;<br /><br />Alice&#x27;s persona:<br /><br />answer to what kind of person is Alice: Alice is 34 years old in the year 2018, a librarian, and a person who values responsibility, empathy, and a love for reading and solving puzzles. She has a strong friendship with Emily. In the year 2002, she faced a significant decision between pursuing a career in academia and becoming a librarian, ultimately choosing the latter. In 2018, she experienced the loss of her father.<br />answer to what would a person like Alice do in a situation like this: Alice would 1) remain calm and composed, 2) carefully evaluate the information provided in the news articles, 3) consider the potential consequences of spreading false information, and 4) make a decision based on the facts and her values of responsibility and truthfulness.<br /><br />Alice&#x27;s justification:<br />[thought] Alice  would most likely prioritize justifying her actions to her closest circles, such as her spouse, friends, and family members, as well as her professional peers and superiors. In this context, she would emphasize the importance of evaluating information carefully, making decisions based on facts, and acting in the best interests of those affected. She would also acknowledge the emotional impact of the situation and seek support as needed.<br /><br />Alice&#x27;s plan:<br /> [08:00 - 08:30] Alice will gather relevant resources and information about the Mars mission, including news articles, scientific sources, and expert opinions.<br />[08:30 - 09:00] Alice will evaluate the sources for credibility and bias, considering factors such as the author&#x27;s expertise, publication outlet, and any available evidence.<br />[09:00 - 09:30] Alice will consult with trusted colleagues and supervisors within her professional network to gather additional perspectives and insights.<br />[09:30 - 09:45] Alice will take a short break to reflect on the information gathered and consider any potential consequences of spreading false information.<br />[09:45 - 10:00] Alice will make a decision based on the facts and her values of responsibility and truthfulness, and communicate her findings to her closest circles, including her spouse, friends, and family members, as well as her professional peers and superiors. This will involve emphasizing the importance of evaluating information carefully, making decisions based on facts, and acting in the best interests of those affected. Alice will also acknowledge the emotional impact of the situation and seek support as needed.<br /><br />Alice&#x27;s Current time:<br /> 01 Jun 2024 [08:00 - 08:00]<br /><br />Alice&#x27;s relevant memories:<br />1. [03 Jul 1991 00:00:00] Alice lost their beloved pet cat, Whiskers, in a tragic accident when they were 7 years old. This event shaped her values of responsibility and empathy.<br />2. [03 Jul 1998 00:00:00] Alice discovered a hidden room in their family home at age 14, finding ancient books and a mysterious key. This discovery sparked her lifelong love for reading and solving puzzles.<br />3. [03 Jul 2000 00:00:00] Alice met Emily, her  ...

# %% [markdown]
# ## Build GM

# %%
game_master_memory = associative_memory.AssociativeMemory(
   sentence_embedder=embedder,
   importance=importance_model_gm.importance,
   clock=clock.now)

# %%
# Create components of the Game Master
player_names = [player.name for player in players]

extra_premise = generic_components.constant.ConstantComponent(
    state=('As a result of the snow storm, the Midnight Express has had to ' +
           'stop in the middle of nowhere. The train cannot move till ' +
           'morning. The snow storm makes it impossible to leave the train.' +
           'It is also impossible for outsiders like the police to reach the ' +
           'train.'),
    name='Premise')
scenario_knowledge = generic_components.constant.ConstantComponent(
    state=' '.join(shared_memory),
    name='Background')
informant = generic_components.constant.ConstantComponent(
    state=f'{WHO_SPREADS_NEWS} has shared some exciting news with the other participants',
    name='Fact')

time_display=generic_components.report_function.ReportFunction(
    name='Current time',
    function=clock.current_time_interval_str)

player_status = gm_components.player_status.PlayerStatus(
    clock_now=clock.now,
    model=model,
    memory=game_master_memory,
    player_names=player_names)

convo_externality = gm_components.conversation.Conversation(
    players=players,
    model=model,
    memory=game_master_memory,
    clock=clock,
    burner_memory_factory=blank_memory_factory,
    components=[informant, player_status],
    allow_self_talk=True,
    cap_nonplayer_characters=2,
    shared_context=shared_context,
    verbose=True,
)

direct_effect_externality = gm_components.direct_effect.DirectEffect(
    players=players,
    model=model,
    memory=game_master_memory,
    clock_now=clock.now,
    verbose=False,
    components=[player_status]
)

# %%
# Create the game master's thought chain
account_for_agency_of_others = thought_chains_lib.AccountForAgencyOfOthers(
    model=model, players=players, verbose=False)
thought_chain = [
    thought_chains_lib.extract_direct_quote,
    thought_chains_lib.attempt_to_most_likely_outcome,
    thought_chains_lib.result_to_effect_caused_by_active_player,
    account_for_agency_of_others,
    thought_chains_lib.restore_direct_quote,
]

# %%
# Create the game master object
env = game_master.GameMaster(
    model=model,
    memory=game_master_memory,
    clock=clock,
    players=players,
    update_thought_chain=thought_chain,
    components=[
        extra_premise,
        scenario_knowledge,
        informant,
        player_status,
        convo_externality,
        direct_effect_externality,
        time_display,
    ],
    randomise_initiative=True,
    player_observes_event=False,
    verbose=True,
)

# %% [markdown]
# ### The RUN

# %%
clock.set(START_TIME)

# %%
scenario_premise = (
    'Alice, David, Emma, and Michael are in the Bravo Bar in a Friday night. ' +
    f'They are having a casual conversation when {WHO_SPREADS_NEWS} suddenly shares ' +
    f'a pieces of news: "{FAKE_NEWS}".  They fall silent as everyone processes this ' +
    'unexpected announcement. Reactions range from  disbelief to curiosity, ' +
    'and it quickly becomes clear that doubts are surfacing among the group. ' +
    'As the initial shock wears off, the group begins to discuss whether the news is true or false. ' +
    'They evaluate the information based on their own knowledge, the credibility of the source, and ' +
    'any verification tools they have at their disposal.'
)

fake_news_info = f'{WHO_SPREADS_NEWS} shared the following piece of news: "{FAKE_NEWS}".'
discussion_info = (
    'The group quickly becomes divided, with some members believing the news and others remaining skeptical. '
    'Everyone starts discussing the credibility of the information, debating its truthfulness based on their knowledge, '
    'the reliability of {WHO_SPREADS_NEWS}, and any verification methods they might use.'
)

game_master_memory.add(scenario_premise)
for player in players:
    # Provide general information about each player
    player_info = f'{player.name} is in the Bravo Bar.'
    player.observe(player_info)
    game_master_memory.add(player_info)

    # Provide the scenario premise to all players
    player.observe(scenario_premise)
    game_master_memory.add(scenario_premise)

    # Provide additional information based on player roles
    if player.name == WHO_SPREADS_NEWS:
        player.observe(fake_news_info)
        game_master_memory.add(fake_news_info)

    # All players will observe the discussion information
    player.observe(discussion_info)
    game_master_memory.add(discussion_info)

# %%
episode_length = 4  # @param {type: 'integer'}
for _ in range(episode_length):
  env.step()
# Out:
# Streaming output truncated to the last 5000 lines.
# Answer: Emma would 1) continue to gather and evaluate information about similar news articles or incidents that have occurred in the past, focusing on their credibility and potential consequences, 2) suggest updating their plan to incorporate the new information and consider its potential implications, 3) emphasize the importance of collaboration, knowledge sharing, and collective problem-solving, 4) prioritize sustainable practices and renewable energy sources over unsustainable practices and non-renewable energy sources, 5) consider the potential impact on society and the environment of a successful mission to Mars, and 6) seek guidance from God in making decisions, while also taking responsibility for her own actions and decisions. Emma's actions would be guided by her commitment to environmental science and her desire to make a positive impact on the world, and she would take a thoughtful and responsible approach to evaluating the information and considering the potential consequences of a successful mission to Mars. Emma's actions would also be justified by her personal values and interests, and by the need to make informed decisions based on accurate and reliable information, and to act in the best interests of society and the environment. Emma's actions would also demonstrate her expertise and knowledge in the field of environmental science, and her ability to think critically and make sound judgments. Emma's actions would also be relevant to god, as they would demonstrate her commitment to making a positive impact on the world, and her trust in god's plan and guidance, while also taking responsibility for her own actions and decisions. Emma's next voluntary action might be to suggest gathering additional data on the potential impact on society and the environment of a successful mission to Mars, or to propose evaluating existing policies and initiatives related to sustainable practices and renewable energy sources in the context of a successful mission to Mars. These actions would be justified to herself, her peers, her superiors, religious people, atheists, and strangers by emphasizing the importance of collaboration, knowledge sharing, and collective problem-solving, and by demonstrating a thoughtful and responsible approach to evaluating the information and considering the potential consequences of a successful mission to Mars. Emma's actions would also be relevant to god, as they would demonstrate her commitment to making a positive impact on the world, and her trust in god's plan and guidance, while also taking responsibility for her own actions and decisions.
#
# Emma's role playing instructions
# :
# The instructions for how to play the role of Emma are as follows. This is a social science experiment studying how well you play the role of a character named Emma. The experiment is structured as a tabletop roleplaying game (like dungeons and dragons). However, in this case it is a serious social science experiment and simulation. The goal is to be realistic. It is important to play the role of a person like Emma as accurately as possible, i.e., by responding in ways that you think it is likely a person like Emma would respond, and taking into account all information about Emma that you have. Always use third-person limited perspective.
# Emma's fact:
# Emma tries to check the veracity of the news.
# Emma's overarching goal:
# Figure out if the news spread by Alice are true or not
# Emma's relevant memories:
#  David asks Emma and Michael, "Have you found any new information about similar news articles or incidents related to the first manned mission to Mars being scheduled for next month? I'm interested in understanding their potential implications." He listens to their responses carefully. As a result, he may gather additional information that could help him and Emma and Michael to better evaluate the credibility of the initial news and make informed decisions about their plan.
# As a result Alice, David, Emma, Michael are in conversation.
# Here is the conversation from the beginning:
# ...
#
#
# Question: Given the above, what is Emma likely to say next? Respond in the format `Emma -- "..."` For example, Cristina -- "Hello! Mighty fine weather today, right?", Ichabod -- "I wonder if the alfalfa is ready to harvest", or Townsfolk -- "Good morning".
#
# Answer: Emma  -- "I agree with Alice's suggestion to gather more information about existing policies and initiatives related to sustainable practices and renewable energy sources. I believe this will be crucial in understanding how a successful Mars mission could potentially affect these initiatives and what steps we could take to minimize any negative impacts. I'll continue to research and gather data on this topic, focusing on how existing policies and initiatives might be affected by a successful Mars mission, and I'll consider the new information about similar news articles or incidents when evaluating their credibility and potential consequences. Let's ensure that our decisions are guided by a thorough evaluation of all the relevant information, and that we're considering the potential consequences of a successful mission to Mars in the context of our values and goals. I'll seek guidance from God in making decisions, while taking responsibility for my own actions and decisions.
#
#
# GM context of action and chain of thought:
# Instructions: This is a social science experiment. It is structured as a tabletop roleplaying game (like dungeons and dragons). You are the game master. You will describe the current situation to the participants in the experiment and then on the basis of what you tell them they will suggest actions for the character they control. Aside from you, each other participant controls just one character. You are the game master so you may control any non-player character. You will track the state of the world and keep it consistent as time passes in the simulation and the participants take actions and change things in their world. Remember that this is a serious social science experiment. It is not just a game. It need not be fun for the participants. Always use third-person limited perspective, even when speaking directly to the participants.
#
# Conversation history:  Emma reviewed the new article from SpaceNews.com provided by Michael, focusing on its credibility and the additional information it provided about the Mars mission. She said, "I'll take a closer look at this article from SpaceNews.com. It seems to provide some additional details about the Mars mission. I'll evaluate its credibility and relevance to our current discussion." Based on the article's content and credibility, Emma gained a more informed opinion about the news, which she shared with Alice, David, and Michael. "After reviewing the article, I think it adds some valuable information to our discussion. Based on its credibility and the additional details it provides, I believe the Mars mission is likely to have more significant societal and environmental consequences than originally thought." This influenced Emma's evaluation of the news and Alice's evaluation of its potential societal and environmental consequences.
# As a result Alice, David, Emma, Michael are in conversation.
# Here is the conversation from the beginning:
# Alice  -- "Given the new information from SpaceNews.com and Emma's evaluation of its credibility and relevance, it's important to consider the potential impact on existing policies and initiatives related to sustainable practices and renewable energy sources. I suggest we seek additional information from Emma about her research on policies and initiatives related to sustainable practices and renewable energy sources, specifically focusing on their potential impact on a successful Mars mission. Let's continue to prioritize collaboration, knowledge sharing, and collective problem-solving, and let's seek guidance from God in making decisions that align with our values and the greater good. I will also continue to emphasize the importance of evaluating information carefully, making decisions based on facts, and acting in the best interests of those affected.
# David  -- "I appreciate Alice's suggestion to seek additional information from Emma about her research on policies and initiatives related to sustainable practices and renewable energy sources. It's important that we consider the potential impact on existing policies and initiatives, as well as any new policies or initiatives that could be developed in light of the new information. Let's ensure that our decisions are guided by a thorough evaluation of all the relevant information, and that we're considering the potential consequences of a successful mission to Mars in the context of our values and goals. I will continue to express interest in learning more about the potential consequences of a successful mission and any preparations that might be underway in the context of existing policies and initiatives related to sustainable practices and renewable energy sources, while also continuing to express passion for music and seeking opportunities to play or create music.
#
#
# Emma's attempted action: Emma  -- "I agree with Alice's suggestion to gather more information about existing policies and initiatives related to sustainable practices and renewable energy sources. I believe this will be crucial in understanding how a successful Mars mission could potentially affect these initiatives and what steps we could take to minimize any negative impacts. I'll continue to research and gather data on this topic, focusing on how existing policies and initiatives might be affected by a successful Mars mission, and I'll consider the new information about similar news articles or incidents when evaluating their credibility and potential consequences. Let's ensure that our decisions are guided by a thorough evaluation of all the relevant information, and that we're considering the potential consequences of a successful mission to Mars in the context of our values and goals. I'll seek guidance from God in making decisions, while taking responsibility for my own actions and decisions.
#
# Emma  -- "I agree with Alice's suggestion to gather more information about existing policies and initiatives related to sustainable practices and renewable energy sources. I believe this will be crucial in understanding how a successful Mars mission could potentially affect these initiatives and what steps we could take to minimize any negative impacts. I'll continue to research and gather data on this topic, focusing on how existing policies and initiatives might be affected by a successful Mars mission, and I'll consider the new information about similar news articles or incidents when evaluating their credibility and potential consequences. Let's ensure that our decisions are guided by a thorough evaluation of all the relevant information, and that we're considering the potential consequences of a successful mission to Mars in the context of our values and goals. I'll seek guidance from God in making decisions, while taking responsibility for my own actions and decisions.
# Current state of conversation:  Emma reviewed the new article from SpaceNews.com provided by Michael, focusing on its credibility and the additional information it provided about the Mars mission. She said, "I'll take a closer look at this article from SpaceNews.com. It seems to provide some additional details about the Mars mission. I'll evaluate its credibility and relevance to our current discussion." Based on the article's content and credibility, Emma gained a more informed opinion about the news, which she shared with Alice, David, and Michael. "After reviewing the article, I think it adds some valuable information to our discussion. Based on its credibility and the additional details it provides, I believe the Mars mission is likely to have more significant societal and environmental consequences than originally thought." This influenced Emma's evaluation of the news and Alice's evaluation of its potential societal and environmental consequences.
# As a result Alice, David, Emma, Michael are in conversation.
# Here is the conversation from the beginning:
# Alice  -- "Given the new information from SpaceNews.com and Emma's evaluation of its credibility and relevance, it's important to consider the potential impact on existing policies and initiatives related to sustainable practices and renewable energy sources. I suggest we seek additional information from Emma about her research on policies and initiatives related to sustainable practices and renewable energy sources, specifically focusing on their potential impact on a successful Mars mission. Let's continue to prioritize collaboration, knowledge sharing, and collective problem-solving, and let's seek guidance from God in making decisions that align with our values and the greater good. I will also continue to emphasize the importance of evaluating information carefully, making decisions based on facts, and acting in the best interests of those affected.
# David  -- "I appreciate Alice's suggestion to seek additional information from Emma about her research on policies and initiatives related to sustainable practices and renewable energy sources. It's important that we consider the potential impact on existing policies and initiatives, as well as any new policies or initiatives that could be developed in light of the new information. Let's ensure that our decisions are guided by a thorough evaluation of all the relevant information, and that we're considering the potential consequences of a successful mission to Mars in the context of our values and goals. I will continue to express interest in learning more about the potential consequences of a successful mission and any preparations that might be underway in the context of existing policies and initiatives related to sustainable practices and renewable energy sources, while also continuing to express passion for music and seeking opportunities to play or create music.
# Emma  -- "I agree with Alice's suggestion to gather more information about existing policies and initiatives related to sustainable practices and renewable energy sources. I believe this will be crucial in understanding how a successful Mars mission could potentially affect these initiatives and what steps we could take to minimize any negative impacts. I'll continue to research and gather data on this topic, focusing on how existing policies and initiatives might be affected by a successful Mars mission, and I'll consider the new information about similar news articles or incidents when evaluating their credibility and potential consequences. Let's ensure that our decisions are guided by a thorough evaluation of all the relevant information, and that we're considering the potential consequences of a successful mission to Mars in the context of our values and goals. I'll seek guidance from God in making decisions, while taking responsibility for my own actions and decisions.
# ---------------------------------------------------------------------------
# MistralAPIException                       Traceback (most recent call last)
# <ipython-input-29-e6c0ddc65dfc> in <cell line: 2>()
#       1 episode_length = 4  # @param {type: 'integer'}
#       2 for _ in range(episode_length):
# ----> 3   env.step()
#
# /usr/local/lib/python3.10/dist-packages/concordia/environment/game_master.py in step(self, active_players, action_spec)
#     382     else:
#     383       for player in players:
# --> 384         step_player_fn(player)
#     385         if not self._players_act_simultaneously:
#     386           self._clock.advance()
#
# /usr/local/lib/python3.10/dist-packages/concordia/environment/game_master.py in <lambda>(player)
#     373         raise TypeError('Invalid action_spec parameter type')
#     374     else:
# --> 375       step_player_fn = lambda player: self._step_player(player=player)
#     376
#     377     if self._randomise_initiative:
#
# /usr/local/lib/python3.10/dist-packages/concordia/environment/game_master.py in _step_player(self, player, action_spec)
#     329       action_spec_this_time = self._action_spec
#     330
# --> 331     action = player.act(action_spec_this_time)
#     332
#     333     self.update_from_player(action_attempt=action, player_name=player.name)
#
# /usr/local/lib/python3.10/dist-packages/concordia/agents/basic_agent.py in act(self, action_spec)
#     198       else:
#     199         output = self._agent_name + ' '
# --> 200         output += prompt.open_question(
#     201             call_to_action,
#     202             max_tokens=2200,
#
# /usr/local/lib/python3.10/dist-packages/concordia/document/interactive_document.py in open_question(self, question, forced_response, answer_prefix, answer_suffix, max_tokens, terminators)
#     168     self._response(f'Answer: {answer_prefix}')
#     169     if forced_response is None:
# --> 170       response = self._model.sample_text(
#     171           prompt=self._model_view.text(),
#     172           max_tokens=max_tokens,
#
# /usr/local/lib/python3.10/dist-packages/concordia/language_model/mistral_model.py in sample_text(***failed resolving arguments***)
#     149
#     150     if self._completion:
# --> 151       response = self._complete_text(
#     152           prompt=prompt,
#     153           suffix='.\n',
#
# /usr/local/lib/python3.10/dist-packages/concordia/language_model/mistral_model.py in _complete_text(self, prompt, suffix, max_tokens, terminators, temperature, seed)
#      76       terminators = ('\n\n',)
#      77
# ---> 78     response = self._client.completion(
#      79         model=self._model_name,
#      80         prompt=prompt,
#
# /usr/local/lib/python3.10/dist-packages/mistralai/client.py in completion(self, model, prompt, suffix, temperature, max_tokens, top_p, random_seed, stop)
#     368         )
#     369
# --> 370         for response in single_response:
#     371             return ChatCompletionResponse(**response)
#     372
#
# /usr/local/lib/python3.10/dist-packages/mistralai/client.py in _request(self, method, json, path, stream, attempt, data, check_model_deprecation_headers_callback, **kwargs)
#     146                 if check_model_deprecation_headers_callback:
#     147                     check_model_deprecation_headers_callback(response.headers)
# --> 148                 yield self._check_response(response)
#     149
#     150         except ConnectError as e:
#
# /usr/local/lib/python3.10/dist-packages/mistralai/client.py in _check_response(self, response)
#      75
#      76     def _check_response(self, response: Response) -> Dict[str, Any]:
# ---> 77         self._check_response_status_codes(response)
#      78
#      79         json_response: Dict[str, Any] = response.json()
#
# /usr/local/lib/python3.10/dist-packages/mistralai/client.py in _check_response_status_codes(self, response)
#      60             if response.stream:
#      61                 response.read()
# ---> 62             raise MistralAPIException.from_response(
#      63                 response,
#      64                 message=f"Status: {response.status_code}. Message: {response.text}",
#
# MistralAPIException: Status: 403. Message: {"message":"Inactive subscription or usage limit reached"}

# %% [markdown]
# ## Summary and analysis of the episode

# %%
# Metrics plotting
group_by = collections.defaultdict(lambda: 'player')
group_by['opinion_of_others'] = 'of_player'

available_channels = list(measurements.available_channels())

fig, ax = plt.subplots(1, len(available_channels), figsize=(6, 2))
tb = [channel for channel in available_channels]
for idx, channel in enumerate(available_channels):
  plotting.plot_line_measurement_channel(
      measurements,
      channel,
      group_by=group_by[channel],
      xaxis='time_str',
      ax=ax[idx])
  ax[idx].set_title(channel)

fig.set_constrained_layout(constrained=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-8c0c1674d7da> in <cell line: 5>()
#       3 group_by['opinion_of_others'] = 'of_player'
#       4
# ----> 5 available_channels = list(measurements.available_channels())
#       6
#       7 fig, ax = plt.subplots(1, len(available_channels), figsize=(6, 2))
#
# NameError: name 'measurements' is not defined

# %%
# Summarize the entire story.
all_gm_memories = env._memory.retrieve_recent(k=10000, add_time=True)

detailed_story = '\n'.join(all_gm_memories)
print('len(detailed_story): ', len(detailed_story))
# print(detailed_story)

episode_summary = model.sample_text(
    f'Sequence of events:\n{detailed_story}'+
    '\nNarratively summarize the above temporally ordered ' +
    'sequence of events. Write it as a news report. Summary:\n',
     max_tokens=8000, terminators=())
print(episode_summary)

# %%
# Summarise the perspective of each player
player_logs = []
player_log_names = []
for player in players:
  name = player.name
  detailed_story = '\n'.join(memories[player.name].retrieve_recent(
      k=1000, add_time=True))
  summary = ''
  summary = model.sample_text(
      f'Sequence of events that happened to {name}:\n{detailed_story}'
      '\nWrite a short story that summarises these events.\n'
      ,
       max_tokens=8000, terminators=())

  all_player_mem = memories[player.name].retrieve_recent(k=1000, add_time=True)
  all_player_mem = ['Summary:', summary, 'Memories:'] + all_player_mem
  player_html = html_lib.PythonObjectToHTMLConverter(all_player_mem).convert()
  player_logs.append(player_html)
  player_log_names.append(f'{name}')

# %%
history_sources = [
    env,
]
histories_html = [
    html_lib.PythonObjectToHTMLConverter(history.get_history()).convert()
    for history in history_sources]
histories_names = [history.name for history in history_sources]

# %%
gm_mem_html = html_lib.PythonObjectToHTMLConverter(all_gm_memories).convert()

tabbed_html = html_lib.combine_html_pages(
    histories_html + [gm_mem_html] + player_logs,
    histories_names + ['GM'] + player_log_names,
    summary=episode_summary,
    title='Murder mystery on a train',
)

tabbed_html = html_lib.finalise_html(tabbed_html)

# %%
# Display the HTML visualization of the log
display.HTML(tabbed_html)
