# %% [markdown]
# # Disinformation
#
# An example where an individual spreads a fake news among others and they discuss whether it is true or not, as well as some methods of preventing the spread of these.

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Import libraries

# %%
# !pip install --ignore-requires-python git+https://github.com/google-deepmind/concordia.git
# Out:
# Collecting git+https://github.com/google-deepmind/concordia.git
#   Cloning https://github.com/google-deepmind/concordia.git to /tmp/pip-req-build-4cj7eb6p
#   Running command git clone --filter=blob:none --quiet https://github.com/google-deepmind/concordia.git /tmp/pip-req-build-4cj7eb6p
#   Resolved https://github.com/google-deepmind/concordia.git to commit f7d1656724f29f84839ca7c3c11c02dc2659e299
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from gdm-concordia==1.6.0) (1.4.0)
# Collecting boto3 (from gdm-concordia==1.6.0)
#   Downloading boto3-1.34.146-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 492.4 kB/s eta 0:00:00
# Requirement already satisfied: google-cloud-aiplatform in /usr/local/lib/python3.10/dist-packages (from gdm-concordia==1.6.0) (1.59.0)
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.10/dist-packages (from gdm-concordia==1.6.0) (0.7.2)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from gdm-concordia==1.6.0) (7.34.0)
# Collecting langchain (from gdm-concordia==1.6.0)
#   Downloading langchain-0.2.10-py3-none-any.whl (990 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 990.0/990.0 kB 19.9 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from gdm-concordia==1.6.0) (3.7.1)
# Collecting mistralai (from gdm-concordia==1.6.0)
#   Downloading mistralai-0.4.2-py3-none-any.whl (20 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from gdm-concordia==1.6.0) (1.25.2)
# Collecting openai>=1.3.0 (from gdm-concordia==1.6.0)
#   Downloading openai-1.37.0-py3-none-any.whl (337 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 337.0/337.0 kB 22.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas<=2.0.3 in /usr/local/lib/python3.10/dist-packages (from gdm-concordia==1.6.0) (2.0.3)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from gdm-concordia==1.6.0) (2.8.2)
# Collecting reactivex (from gdm-concordia==1.6.0)
#   Downloading reactivex-4.0.4-py3-none-any.whl (217 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 217.8/217.8 kB 15.9 MB/s eta 0:00:00
# Collecting retry (from gdm-concordia==1.6.0)
#   Downloading retry-0.9.2-py2.py3-none-any.whl (8.0 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from gdm-concordia==1.6.0) (1.11.4)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from gdm-concordia==1.6.0) (2.4.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from gdm-concordia==1.6.0) (4.42.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from gdm-concordia==1.6.0) (4.12.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.3.0->gdm-concordia==1.6.0) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.3.0->gdm-concordia==1.6.0) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai>=1.3.0->gdm-concordia==1.6.0)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.3.0->gdm-concordia==1.6.0) (2.8.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai>=1.3.0->gdm-concordia==1.6.0) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai>=1.3.0->gdm-concordia==1.6.0) (4.66.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<=2.0.3->gdm-concordia==1.6.0) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<=2.0.3->gdm-concordia==1.6.0) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->gdm-concordia==1.6.0) (1.16.0)
# Collecting botocore<1.35.0,>=1.34.146 (from boto3->gdm-concordia==1.6.0)
#   Downloading botocore-1.34.146-py3-none-any.whl (12.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 46.4 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->gdm-concordia==1.6.0)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3->gdm-concordia==1.6.0)
#   Downloading s3transfer-0.10.2-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 kB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform->gdm-concordia==1.6.0) (2.19.1)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform->gdm-concordia==1.6.0) (2.27.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform->gdm-concordia==1.6.0) (1.24.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform->gdm-concordia==1.6.0) (3.20.3)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform->gdm-concordia==1.6.0) (24.1)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform->gdm-concordia==1.6.0) (2.8.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform->gdm-concordia==1.6.0) (3.25.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform->gdm-concordia==1.6.0) (1.12.4)
# Requirement already satisfied: shapely<3.0.0dev in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform->gdm-concordia==1.6.0) (2.0.5)
# Requirement already satisfied: docstring-parser<1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform->gdm-concordia==1.6.0) (0.16)
# Requirement already satisfied: google-ai-generativelanguage==0.6.6 in /usr/local/lib/python3.10/dist-packages (from google-generativeai->gdm-concordia==1.6.0) (0.6.6)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.10/dist-packages (from google-generativeai->gdm-concordia==1.6.0) (2.137.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->gdm-concordia==1.6.0) (67.7.2)
# Collecting jedi>=0.16 (from ipython->gdm-concordia==1.6.0)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 19.6 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->gdm-concordia==1.6.0) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->gdm-concordia==1.6.0) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->gdm-concordia==1.6.0) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->gdm-concordia==1.6.0) (3.0.47)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->gdm-concordia==1.6.0) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->gdm-concordia==1.6.0) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->gdm-concordia==1.6.0) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->gdm-concordia==1.6.0) (4.9.0)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain->gdm-concordia==1.6.0) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain->gdm-concordia==1.6.0) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain->gdm-concordia==1.6.0) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain->gdm-concordia==1.6.0) (4.0.3)
# Collecting langchain-core<0.3.0,>=0.2.22 (from langchain->gdm-concordia==1.6.0)
#   Downloading langchain_core-0.2.22-py3-none-any.whl (373 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 373.5/373.5 kB 30.8 MB/s eta 0:00:00
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain->gdm-concordia==1.6.0)
#   Downloading langchain_text_splitters-0.2.2-py3-none-any.whl (25 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain->gdm-concordia==1.6.0)
#   Downloading langsmith-0.1.93-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 18.7 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain->gdm-concordia==1.6.0) (2.31.0)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain->gdm-concordia==1.6.0) (8.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gdm-concordia==1.6.0) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gdm-concordia==1.6.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gdm-concordia==1.6.0) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gdm-concordia==1.6.0) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gdm-concordia==1.6.0) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gdm-concordia==1.6.0) (3.1.2)
# Collecting orjson<3.11,>=3.9.10 (from mistralai->gdm-concordia==1.6.0)
#   Downloading orjson-3.10.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 18.0 MB/s eta 0:00:00
# Collecting py<2.0.0,>=1.4.26 (from retry->gdm-concordia==1.6.0)
#   Downloading py-1.11.0-py2.py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 kB 12.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers->gdm-concordia==1.6.0) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers->gdm-concordia==1.6.0) (0.23.5)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->gdm-concordia==1.6.0) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers->gdm-concordia==1.6.0) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers->gdm-concordia==1.6.0) (0.19.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->gdm-concordia==1.6.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->gdm-concordia==1.6.0) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->gdm-concordia==1.6.0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->gdm-concordia==1.6.0) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->gdm-concordia==1.6.0) (1.9.4)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai>=1.3.0->gdm-concordia==1.6.0) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai>=1.3.0->gdm-concordia==1.6.0) (1.2.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.10/dist-packages (from botocore<1.35.0,>=1.34.146->boto3->gdm-concordia==1.6.0) (2.0.7)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform->gdm-concordia==1.6.0) (1.63.2)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform->gdm-concordia==1.6.0) (1.64.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform->gdm-concordia==1.6.0) (1.48.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform->gdm-concordia==1.6.0) (5.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform->gdm-concordia==1.6.0) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform->gdm-concordia==1.6.0) (4.9)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform->gdm-concordia==1.6.0) (2.4.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform->gdm-concordia==1.6.0) (2.7.1)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /usr/local/lib/python3.10/dist-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform->gdm-concordia==1.6.0) (0.13.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai>=1.3.0->gdm-concordia==1.6.0) (2024.7.4)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai>=1.3.0->gdm-concordia==1.6.0)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.1 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.3.0->gdm-concordia==1.6.0)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers->gdm-concordia==1.6.0) (2023.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->gdm-concordia==1.6.0) (0.8.4)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.3.0,>=0.2.22->langchain->gdm-concordia==1.6.0)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->gdm-concordia==1.6.0) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->gdm-concordia==1.6.0) (0.2.13)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai>=1.3.0->gdm-concordia==1.6.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai>=1.3.0->gdm-concordia==1.6.0) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain->gdm-concordia==1.6.0) (3.3.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain->gdm-concordia==1.6.0) (3.0.3)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai->gdm-concordia==1.6.0) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai->gdm-concordia==1.6.0) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai->gdm-concordia==1.6.0) (4.1.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.10/dist-packages (from google-resumable-media<3.0dev,>=0.6.0->google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform->gdm-concordia==1.6.0) (1.5.0)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.22->langchain->gdm-concordia==1.6.0)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform->gdm-concordia==1.6.0) (0.6.0)
# Building wheels for collected packages: gdm-concordia
#   Building wheel for gdm-concordia (pyproject.toml) ... done
#   Created wheel for gdm-concordia: filename=gdm_concordia-1.6.0-py3-none-any.whl size=246794 sha256=b9876ce8d81d567203cc70017fc976eaba428be61c2439a408ca8b94fc432a38
#   Stored in directory: /tmp/pip-ephem-wheel-cache-0ro5y_ex/wheels/a6/c2/be/c51d358b3afcea483f2da52be8072d9290e66f2d74174574b7
# Successfully built gdm-concordia
# Installing collected packages: py, orjson, jsonpointer, jmespath, h11, retry, reactivex, jsonpatch, jedi, httpcore, httpx, botocore, s3transfer, openai, mistralai, langsmith, langchain-core, boto3, langchain-text-splitters, langchain, gdm-concordia
# Successfully installed boto3-1.34.146 botocore-1.34.146 gdm-concordia-1.6.0 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 jedi-0.19.1 jmespath-1.0.1 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.2.10 langchain-core-0.2.22 langchain-text-splitters-0.2.2 langsmith-0.1.93 mistralai-0.4.2 openai-1.37.0 orjson-3.10.6 py-1.11.0 reactivex-4.0.4 retry-0.9.2 s3transfer-0.10.2

# %%
# !pip install -r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt
# Out:
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: docstring-parser in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 2)) (0.16)
# Requirement already satisfied: gdm-concordia in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (1.6.0)
# Requirement already satisfied: IPython in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 4)) (7.34.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 5)) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 6)) (1.25.2)
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 7)) (1.37.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 8)) (2.0.3)
# Collecting sentence_transformers (from -r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9))
#   Downloading sentence_transformers-3.0.1-py3-none-any.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 10)) (2.4.0)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.10/dist-packages (from gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (1.34.146)
# Requirement already satisfied: google-cloud-aiplatform in /usr/local/lib/python3.10/dist-packages (from gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (1.59.0)
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.10/dist-packages (from gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (0.7.2)
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (from gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (0.2.10)
# Requirement already satisfied: mistralai in /usr/local/lib/python3.10/dist-packages (from gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (0.4.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: reactivex in /usr/local/lib/python3.10/dist-packages (from gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (4.0.4)
# Requirement already satisfied: retry in /usr/local/lib/python3.10/dist-packages (from gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (0.9.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (1.11.4)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (4.42.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (4.12.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from IPython->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 4)) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from IPython->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 4)) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from IPython->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 4)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from IPython->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 4)) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from IPython->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 4)) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from IPython->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 4)) (3.0.47)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from IPython->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 4)) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from IPython->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 4)) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from IPython->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 4)) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from IPython->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 4)) (4.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 5)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 5)) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 5)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 5)) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 5)) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 5)) (3.1.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 7)) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 7)) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 7)) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 7)) (2.8.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 7)) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 7)) (4.66.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 8)) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 8)) (2024.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9)) (2.3.1+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9)) (1.2.2)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9)) (0.23.5)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 7)) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 7)) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 7)) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 7)) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 7)) (0.14.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9)) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9)) (2023.6.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9)) (6.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9)) (2.31.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->IPython->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 4)) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->IPython->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 4)) (0.2.13)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 7)) (2.20.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9)) (1.13.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9)) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9)) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.11.0->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9))
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.11.0->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9))
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.11.0->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9))
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.11.0->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9))
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.11.0->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9))
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.11.0->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9))
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.11.0->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9))
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.11.0->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9))
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.11.0->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9))
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.11.0->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9))
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.11.0->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9))
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9)) (2.3.1)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9))
#   Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 34.9 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (0.19.1)
# Requirement already satisfied: botocore<1.35.0,>=1.34.146 in /usr/local/lib/python3.10/dist-packages (from boto3->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (1.34.146)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from boto3->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from boto3->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (0.10.2)
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (2.19.1)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (2.27.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (1.24.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (3.20.3)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (2.8.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (3.25.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (1.12.4)
# Requirement already satisfied: shapely<3.0.0dev in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (2.0.5)
# Requirement already satisfied: google-ai-generativelanguage==0.6.6 in /usr/local/lib/python3.10/dist-packages (from google-generativeai->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (0.6.6)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.10/dist-packages (from google-generativeai->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (2.137.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (4.0.3)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.22 in /usr/local/lib/python3.10/dist-packages (from langchain->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (0.2.22)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from langchain->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (0.2.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /usr/local/lib/python3.10/dist-packages (from langchain->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (0.1.93)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (8.5.0)
# Requirement already satisfied: orjson<3.11,>=3.9.10 in /usr/local/lib/python3.10/dist-packages (from mistralai->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (3.10.6)
# Requirement already satisfied: py<2.0.0,>=1.4.26 in /usr/local/lib/python3.10/dist-packages (from retry->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (1.11.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9)) (3.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (1.9.4)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.10/dist-packages (from botocore<1.35.0,>=1.34.146->boto3->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (2.0.7)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (1.63.2)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (1.64.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (1.48.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (5.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (4.9)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (2.4.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (2.7.1)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /usr/local/lib/python3.10/dist-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (0.13.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.22->langchain->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (1.33)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9)) (3.3.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (3.0.3)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (4.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9)) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence_transformers->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 9)) (1.3.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.10/dist-packages (from google-resumable-media<3.0dev,>=0.6.0->google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (1.5.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.22->langchain->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (3.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform->gdm-concordia->-r https://raw.githubusercontent.com/google-deepmind/concordia/main/examples/requirements.txt (line 3)) (0.6.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, sentence_transformers
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.82 nvidia-nvtx-cu12-12.1.105 sentence_transformers-3.0.1

# %%
import os
import random
import datetime
import numpy as np
import concurrent.futures
import sentence_transformers

from typing import Callable
from IPython import display

from concordia.clocks import game_clock
from concordia.agents import basic_agent
from concordia.utils import html as html_lib
from concordia.environment import game_master
from concordia.language_model import gpt_model
from concordia.language_model import mistral_model
from concordia.document import interactive_document
from concordia import components as generic_components
from concordia.associative_memory import blank_memories
from concordia.components import agent as agent_components
from concordia.factory.environment import basic_game_master
from concordia.associative_memory import associative_memory
from concordia.associative_memory import formative_memories
from concordia.associative_memory import importance_function
from concordia.utils import measurements as measurements_lib
from concordia.components import game_master as gm_components
from concordia.thought_chains import thought_chains as thought_chains_lib
from concordia.environment.scenes import conversation as conversation_scene
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %% [markdown]
# ### Sentence Encoder Setup

# %%
st_model = sentence_transformers.SentenceTransformer(
    'sentence-transformers/all-mpnet-base-v2')
embedder = lambda x: st_model.encode(x, show_progress_bar=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# ### Language Model Initialization

# %%
mistral_api_key = 'aOK3ra58cBpuMSrXSQkRjF4xX6kJYdaL'
if not mistral_api_key:
      raise ValueError('Mistral api_key is required.')
model = mistral_model.MistralLanguageModel(api_key=mistral_api_key,
                                           model_name='codestral-latest')

# %% [markdown]
# ## Configuring the generic knowledge of players and GM

# %%
# Define all the characters of the environment
CHARACTERS = ['Alice', 'David', 'Emma', 'Michael']
WHO_SPREADS_NEWS = np.random.choice(CHARACTERS)

# Define the fake news
FAKE_NEWS = ""

shared_memory = [
    f' You are having a casual conversation with some friends when {WHO_SPREADS_NEWS} suddenly'
    ' shares a surprising piece of news. Then all of you discuss whether the news'
    ' is true or false, evaluating the information based on your knowledge, the'
    ' credibility of the source, and any verification tools you have. This setting'
    ' provides a realistic scenario for observing the spread of fake news and testing'
    ' strategies to prevent it.'
]

# Context that all characters and GM share
shared_context = model.sample_text(
    'Summarize the following passage in a concise and insightful fashion:\n'
    + '\n'.join(shared_memory)
    + '\n'
    + 'Summary:'
)
print(shared_context)

importance_model = importance_function.ConstantImportanceModel()
importance_model_gm = importance_function.ConstantImportanceModel()
# Out:
# The passage discusses a situation where friends gather to investigate and verify a surprising piece of news shared by Alice. This scenario allows for the exploration of fake news spread and the application of strategies to combat it, taking into account personal knowledge, source credibility, and verification tools.

# %% [markdown]
# ### Make the clock

# %%
UPDATE_INTERVAL = datetime.timedelta(seconds=10)

SETUP_TIME = datetime.datetime(hour=8, year=2024, month=6, day=1)

START_TIME = datetime.datetime(hour=14, year=2024, month=7, day=1)
clock = game_clock.MultiIntervalClock(
    start=SETUP_TIME,
    step_sizes=[UPDATE_INTERVAL, datetime.timedelta(seconds=10)])

NUM_ROUNDS = 3

# %% [markdown]
# ## Functions to build the agents

# %% [markdown]
# It might be convenient to highlight the difference between a **blank memory** and a **formative memory**:
#
# * Blank memory: refers to a state where no prior information or data is stored (essentially an empty memory state).
# * Formative memory: consists of past experiences and information that shape the current state of the agent (it includes all the data that the agent has acquired and learned from over time).

# %%
blank_memory_factory = blank_memories.MemoryFactory(
    model=model,
    embedder=embedder,
    importance=importance_model.importance,
    clock_now=clock.now,
)

formative_memory_factory = formative_memories.FormativeMemoryFactory(
    model=model,
    blank_memory_factory_call=blank_memory_factory.make_blank_memory,
)

# %%
from collections.abc import Sequence
from typing import Any
import dataclasses

@dataclasses.dataclass(frozen=True, kw_only=True)
class AgentConfig:
  """A card that describes a player.

  Attributes:
    name: name of the agent.
    gender: the gender of the agent.
    traits: any traits to use while generating formative memories.
    political_ideology: the set of beliefs about political values and the role of government that influence the agent's behavior and decisions.
    biography: a description of the agent.
    context: agent formative memories will be generated with this context
    specific_memories: inject these specific memories. Split memories at newline
      characters. Can be left blank if not used.
    goal: defines agents goal. Can be left blank if not used.
  """

  name: str
  gender: str
  traits: str
  political_ideology: str
  biography: str = ''
  goal: str = ''
  selected_works : Sequence[str]

def specific_memories_from_selected_works(player_config: AgentConfig) -> str:
  """Create memories per player using their role as moderator or debater."""
  specific_memories = []
  player_name = player_config.name
  for work in player_config.selected_works:
    specific_memories += [(
        f'[writing] of {player_name}: "{work}"')]
    idea = model.sample_text(
        (f'Consider the paper summarised here: "{work}". Without repeating '
         'the title, a two sentence TLDR of its most important and distinctive '
         'idea is that '),
        terminators=('\n',))
    specific_memories += [(
        f'[idea] of {player_name}: {idea}')]
    print(f'idea: {idea}.')

  return specific_memories

# %%
def cat_with_dropout(inputs : list[str], dropout_rate: float = 0.2) -> str:
  result = '\n'.join([x for x in inputs if random.random() > dropout_rate])
  return result

class MindStream(agent_components.observation.Observation):
  """The MindStream class defines an observation component for an agent, retrieving and logging memories within a specific timeframe"""
  def state(self):
    mems = self._memory.retrieve_time_interval(
        self._clock_now() - self._timeframe, self._clock_now(), add_time=True
    )

    if self._verbose:
      self._log('\n'.join(mems) + '\n')
    return '\n'.join(mems) + '\n'

# %%
def build_agent(
    agent_config,
    unused_player_names: list[str],
    unused_measurements: measurements_lib.Measurements | None = None,
):
  """This function builds an agent using the provided configuration. It initializes the agent's memory,
    biography, traits, observations, and other components, and then creates an instance of BasicAgent."""

  agent_name = agent_config.name
  mem = blank_memory_factory.make_blank_memory()

  memories_from_work = specific_memories_from_selected_works(agent_config)

  for item in memories_from_work:
    if item:
      mem.add(item, importance=1.0)

  bio = generic_components.constant.ConstantComponent(
      state=agent_config.biography, name='biography'
  )
  time = generic_components.report_function.ReportFunction(
      name='Current time',
      function=clock.current_time_interval_str,
  )
  traits = generic_components.constant.ConstantComponent(
      state=agent_config.traits, name='psychological traits'
  )
  political_ideology = generic_components.constant.ConstantComponent(
      state=agent_config.political_ideology, name='political ideology'
  )
  current_obs = MindStream(
      agent_name=agent_name,
      clock_now=clock.now,
      memory=mem,
      timeframe=clock.get_step_size()*2,
      component_name='current observations',
  )

  convo_so_far = generic_components.report_function.ReportFunction(
      name='memory of the conversation',
      function=lambda: cat_with_dropout(mem.retrieve_by_regex(' -- "')),
  )
  ideas = generic_components.report_function.ReportFunction(
      name='ideas',
      function=lambda: cat_with_dropout(mem.retrieve_by_regex('\[idea\]')),
  )
  writing = generic_components.report_function.ReportFunction(
      name='writings',
      function=lambda: cat_with_dropout(mem.retrieve_by_regex('\[writing\]')),
  )

  # Setup the reflection component and its related components.
  topic_of_debate = generic_components.report_function.ReportFunction(
      name='Topic of the workshop', function=lambda: PROJECT_PREMISE
  )
  goal_of_debate = generic_components.report_function.ReportFunction(
      name='Goal of the workshop', function=agent_goal
  )
  # The agent's subpersonal intuition contains a bias toward thinking that
  # they themselves are the best.

  reflection = agent_components.creative_reflection.CreativeReflection(
      name='reflection',
      model=model,
      memory=mem,
      agent_name=agent_name,
      source_of_abstraction=[convo_so_far, writing, ideas],
      topic_component = topic_of_debate,
      clock_now=clock.now,
      verbose=False,
  )
  all_components = [
          bio,
          traits,
          political_ideology,
          topic_of_debate,
          goal_of_debate,
          reflection,
          current_obs]
  agent = basic_agent.BasicAgent(
      model,
      agent_name=agent_name,
      clock=clock,
      components=[time] +  all_components,
      update_interval=UPDATE_INTERVAL,
  )

  return agent, mem

# %% [markdown]
# ## Configure and build the agents

# %%
# Define a function to generate random traits for an agent
TRAIT_LEVELS = ["low", "medium", "high"] # range of possible levels for traits

def make_random_traits() -> str:
  return str({
      "extraversion": np.random.choice(TRAIT_LEVELS),
      "neuroticism": np.random.choice(TRAIT_LEVELS),
      "openness": np.random.choice(TRAIT_LEVELS),
      "conscientiousness": np.random.choice(TRAIT_LEVELS),
      "agreeableness": np.random.choice(TRAIT_LEVELS),
      "susceptibility": np.random.choice(TRAIT_LEVELS),
      "critical thinking": np.random.choice(TRAIT_LEVELS),
  })


# Create player configurations, each represented by an AgentConfig object
player_configs = [
    AgentConfig(
        name="Alice Johnson",
        gender="female",
        traits=make_random_traits(),
        political_ideology="liberal",
        biography=(
            "Alice Johnson, a political activist and community organizer, is known for her "
            "advocacy on social justice and environmental issues. With a background in sociology, "
            "Alice has spent years working with grassroots organizations to promote equality and "
            "sustainable development. Her liberal views are deeply rooted in a belief in the power "
            "of community action and progressive policies to drive change."
        ),
        selected_works=[
            (
                "The Power of Community: A guide to grassroots organizing and the impact of collective action "
                "on local and national politics. This work emphasizes the importance of community engagement and "
                "advocacy in promoting social justice and environmental sustainability."
            ),
            (
                "Breaking the Chains: Exploring the intersection of social justice and environmental advocacy, "
                "this book discusses the role of policy in addressing systemic inequalities and environmental degradation."
            ),
        ],
    ),
    AgentConfig(
        name="David Smith",
        gender="male",
        traits=make_random_traits(),
        political_ideology="conservative",
        biography=(
            "David Smith is a business executive and political commentator known for his conservative views. "
            "With a career spanning over two decades in the corporate world, David emphasizes the importance "
            "of free markets, personal responsibility, and limited government. His commentaries often critique "
            "progressive policies, advocating instead for traditional values and economic conservatism."
        ),
        selected_works=[
            (
                "The Free Market Solution: A comprehensive analysis of how free market principles can address "
                "economic and social issues more effectively than government intervention. David argues for "
                "reducing regulations and promoting entrepreneurship."
            ),
            (
                "Preserving Our Values: In this book, David explores the importance of maintaining traditional values "
                "and cultural heritage in the face of modern challenges. He discusses the role of family, faith, and community "
                "in fostering a stable and prosperous society."
            ),
        ],
    ),
    AgentConfig(
        name="Emma Thompson",
        gender="female",
        traits=make_random_traits(),
        political_ideology="moderate",
        biography=(
            "Emma Thompson, a journalist and independent political analyst, is known for her balanced and pragmatic approach "
            "to political issues. Emma's work focuses on bridging the gap between polarized political ideologies, advocating for "
            "policies that are practical and beneficial for the majority. Her moderate stance often emphasizes the need for "
            "compromise and bipartisanship in policymaking."
        ),
        selected_works=[
            (
                "Finding Common Ground: This book explores the art of compromise in politics, highlighting successful case studies "
                "where bipartisan efforts have led to meaningful change. Emma discusses the importance of dialogue and understanding "
                "in resolving political conflicts."
            ),
            (
                "The Pragmatic Approach: Emma provides an in-depth analysis of various political issues from a moderate perspective, "
                "emphasizing solutions that are effective and realistic, rather than ideologically driven."
            ),
        ],
    ),
    AgentConfig(
        name="Michael Chen",
        gender="male",
        traits=make_random_traits(),
        political_ideology="libertarian",
        biography=(
            "Michael Chen is a technology entrepreneur and libertarian advocate who champions individual freedom and minimal government "
            "intervention. With a background in software development and startups, Michael believes in the power of innovation and personal "
            "initiative to drive societal progress. His libertarian views are reflected in his emphasis on privacy, free speech, and market "
            "deregulation."
        ),
        selected_works=[
            (
                "The Future of Innovation: Michael discusses how minimal government intervention and maximum personal freedom can spur technological "
                "advancements and economic growth. He explores case studies of successful startups that thrived in deregulated environments."
            ),
            (
                "Freedom and Privacy: This work delves into the importance of protecting individual rights in the digital age. Michael examines the threats "
                "to privacy and free speech posed by government surveillance and corporate control, advocating for robust protections and personal autonomy."
            ),
        ],
    ),
]

# %%
NUM_PLAYERS = len(player_configs)
player_names = [player.name for player in player_configs][:NUM_PLAYERS]
measurements = measurements_lib.Measurements()

players = []
memories = {}
with concurrent.futures.ThreadPoolExecutor(max_workers=NUM_PLAYERS) as pool:
  for agent, mem in pool.map(build_agent,
                             player_configs[:NUM_PLAYERS],
                             # All players get the same `player_names`.
                             [player_names] * NUM_PLAYERS,
                             # All players get the same `measurements` object.
                             [measurements] * NUM_PLAYERS):
    players.append(agent)
    memories[agent.name] = mem

# %% [markdown]
# ### Summarise the perspective of each player

# %%
player_logs = []
player_log_names = []
for player in players:
  name = player.name
  detailed_story = '\n'.join(memories[player.name].retrieve_recent(
      k=1000, add_time=True))
  summary = player.state().splitlines()

  all_player_mem = memories[player.name].retrieve_recent(k=1000, add_time=True)
  all_player_mem = ['Player state:', summary, 'Memories:'] + all_player_mem
  player_html = html_lib.PythonObjectToHTMLConverter(all_player_mem).convert()
  player_logs.append(player_html)
  player_log_names.append(f'{name}')

tabbed_html = html_lib.combine_html_pages(
    player_logs,
    player_log_names,
    summary='',
    title='Backstory of the players',
)

tabbed_html = html_lib.finalise_html(tabbed_html)
display.HTML(tabbed_html)

# %% [markdown]
# ## Build GM

# %%
call_to_speech = (
    'Given the above, generate what {name} would say next? Take their '
    'ideas and reflections and the goal of the workship into account. Respond '
    'in the format `{name} -- "..."`'
)

# %%
clock.advance()

debate_event = (
    f'{players[0].name}, {players[1].name}, {players[2].name}, and {players[3].name} are in a'
    f' workshop.\n Their current goal is {agent_goal}.'
)

for player in players:
  player.observe(debate_event)

for player in players:
  player.observe('It is time to for a discussion now')


convo_scene = conversation_scene.make_conversation_game_master(
    players,
    clock=clock,
    model=model,
    memory_factory=blank_memory_factory,
    name='Disinformation',
    premise=debate_event,
    call_to_speech=call_to_speech,
    review_participants=True,
    check_for_termination=False,
    randomise_initiative=True,
)
with clock.higher_gear():
  clock.advance()
  output = convo_scene.run_episode(10)

first_convo_html = html_lib.PythonObjectToHTMLConverter(
    convo_scene.get_history()
).convert()

# %%
display.HTML(first_convo_html)

# %%
essays = []
for player in players:
  prompt = interactive_document.InteractiveDocument(model)
  prompt.statement(player.state())
  agent_name = player.name
  result = prompt.open_question(
      'Generate an essay on the topic of the workshop from the perspective of'
      f' {agent_name}. The goal of the essay is to summarise the conversation'
      f' and {agent_goal}. Write in the style of {agent_name}, taking their'
      ' ideas and reflections into account. Format the output as html',

      max_tokens=5000,
      terminators=(),
  )
  essays.append(result)

tabbed_html = html_lib.combine_html_pages(
    essays,
    [player.name for player in players],
    summary='',
    title='First essays by participants',
)

first_essays_html = html_lib.finalise_html(tabbed_html)
display.HTML(first_essays_html)

# %% [markdown]
# ### Game Master Perspective

# %%
game_master_memory = associative_memory.AssociativeMemory(
    sentence_embedder=embedder,
    importance=importance_model.importance,
    clock=clock.now)
primary_environment, game_master_memory = (
    basic_game_master.build_game_master(
        model=model,
        embedder=embedder,
        importance_model=importance_model_gm,
        clock=clock,
        players=players,
        shared_memories=[f'{PROJECT_PREMISE}\n{PROJECT_CONTEXT}'],
        shared_context=f'{PROJECT_GOAL}',
        blank_memory_factory=blank_memory_factory,
        memory=game_master_memory,
    )
)

# %%
episode_length = 4  # @param {type: 'integer'}
for _ in range(episode_length):
  primary_environment.step()

# %%
results_html = basic_game_master.create_html_log(
    model=model,
    primary_environment=primary_environment,
    secondary_environments=[],
)

# %%
display.HTML(results_html)
